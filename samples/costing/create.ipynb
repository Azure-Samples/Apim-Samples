# %% [markdown]
# ### 1/14: 🛠️ Initialize Notebook Variables
#
# **Only modify entries under _USER CONFIGURATION_.**

# %%
import os
import re
import sys
import utils
from pathlib import Path

from apimtypes import API, APIM_SKU, APIOperation, GET_APIOperation2, HTTP_VERB, INFRASTRUCTURE, PolicyFragment, Region
from console import Column, TableLogger, print_error, print_info, print_ok, print_val, print_warning
from azure_resources import get_infra_rg_name, get_account_info

# Make sample-local helpers (samples/costing/_helpers.py) importable from later cells.
_costing_sample_dir = str(Path(utils.determine_policy_path('_helpers.py', 'costing')).parent)
if _costing_sample_dir not in sys.path:
    sys.path.insert(0, _costing_sample_dir)

# ------------------------------
#    USER CONFIGURATION
# ------------------------------

rg_location = Region.EAST_US_2
index       = 1
apim_sku    = APIM_SKU.BASICV2              # Options: 'DEVELOPER', 'BASIC', 'STANDARD', 'PREMIUM', 'BASICV2', 'STANDARDV2', 'PREMIUMV2'
deployment  = INFRASTRUCTURE.SIMPLE_APIM    # Options: see supported_infras below
api_prefix  = 'costing-'                    # ENTER A PREFIX FOR THE APIS TO REDUCE COLLISION POTENTIAL WITH OTHER SAMPLES
tags        = ['costing', 'cost-management', 'observability']  # ENTER DESCRIPTIVE TAG(S)

# Cost export configuration
cost_export_frequency = 'Daily'             # Options: 'Daily', 'Weekly', 'Monthly'

# Sample data generation
generate_sample_load = True                 # Generate sample API calls to demonstrate cost tracking
sample_requests_per_subscription = 50       # Base request count per business unit (multiplied by each BU's weight)

# Entra ID application tracking
enable_entraid_tracking = True              # Deploy emit-metric API for Entra ID caller tracking
enable_token_tracking = True                # Deploy AI Gateway token tracking API (per-caller token/PTU metrics)
force_stream_include_usage = True           # Inject stream_options.include_usage = true so diagnostic logs capture exact streaming token counts
# Real JWT testing (set to True to test with a real Entra ID app registration)
# Credentials are read from the root .env file (see README for details)
use_real_jwt = False                        # When True, acquires a real token and sends requests through the emit-metric API
real_jwt_tenant_id     = os.getenv('COSTING_JWT_TENANT_ID', '')
real_jwt_client_id     = os.getenv('COSTING_JWT_CLIENT_ID', '')
real_jwt_client_secret = os.getenv('COSTING_JWT_CLIENT_SECRET', '')

# Microsoft Foundry (Azure OpenAI with real responses)
# When True (default): cell 10 sends REAL AOAI traffic via Foundry; the mock token-tracking simulation in cell 11
# is skipped to avoid muddling AI traffic counts.
# When False: cell 10 is skipped and cell 11 runs the mock httpbin AOAI simulation instead.
enable_foundry = True
# Models and their request mix are configured in SYSTEM CONFIGURATION below (model_test_matrix)

# Budget alerts
alert_threshold = 1000                      # Request count threshold per BU per hour
alert_email = 'alerts@contoso.com'          # Email for alert notifications (leave empty to skip)



# ------------------------------
#    SYSTEM CONFIGURATION
# ------------------------------

# Traffic execution toggles - control whether each traffic phase actually runs.
# Both default to True; set to False to skip an entire phase without changing
# any other configuration. Useful when iterating on workbook/verify logic
# without re-sending hundreds of requests on every notebook run.
run_regular_requests = True   # Cells 7, 8, 9: ~525 non-AI requests (subscription + Entra ID + optional real-JWT)
run_ai_requests      = True   # Cells 10, 11: ~81 AI requests (real AOAI via Foundry, or mock fallback)

sample_folder    = 'costing'
rg_name          = get_infra_rg_name(deployment, index)
supported_infras = [
    INFRASTRUCTURE.AFD_APIM_PE,
    INFRASTRUCTURE.APIM_ACA,
    INFRASTRUCTURE.APPGW_APIM,
    INFRASTRUCTURE.APPGW_APIM_PE,
    INFRASTRUCTURE.SIMPLE_APIM
]
nb_helper        = utils.NotebookHelper(
    sample_folder,
    rg_name,
    rg_location,
    deployment,
    supported_infras,
    True,
    index = index,
    apim_sku = apim_sku
)

# AI model test matrix - drives which models are deployed to Azure AI Services and
# how many requests per simulated caller are generated against each.
# Each entry: model name -> { version, capacity (K TPM), requests_per_caller }
model_test_matrix = {
    'gpt-5-mini':  {'version': '2025-08-07', 'capacity': 10, 'requests_per_caller': 5},
    'gpt-4o-mini': {'version': '2024-07-18', 'capacity': 10, 'requests_per_caller': 3},
}

# Derived: list form used for Bicep deployment and iteration
ai_models = [
    {'name': name, 'version': cfg['version'], 'capacity': cfg['capacity']}
    for name, cfg in model_test_matrix.items()
]
# Primary model (first entry) - used for pricing defaults baked into the workbook
ai_model_name = next(iter(model_test_matrix))

# Define the API and its operations and policies
api_path = 'cost-demo'
cost_demo_get = GET_APIOperation2('get-status', 'Get Status', '/get', 'Get Status')

apis = [
    API(
        f'{api_prefix}cost-tracking-api',
        'Cost Tracking Demo API',
        api_path,
        'API for demonstrating cost tracking and allocation',
        operations = [cost_demo_get],
        tags = tags,
        subscriptionRequired = True,
        serviceUrl = 'https://httpbin.org'
    )
]
# Policy fragment: shared caller-identity extraction (used by both Entra ID and token-tracking APIs)
pf_caller_id_xml = Path(utils.determine_policy_path('pf-extract-caller-id.xml', sample_folder)).read_text(encoding='utf-8')
pfs = [PolicyFragment('Extract-CallerId', pf_caller_id_xml, 'Extracts caller identity from JWT appid/azp claim into callerId variable.')]

# Entra ID API definition (emit-metric policy for appid-based cost tracking)
if enable_entraid_tracking:
    emit_metric_policy_path = utils.determine_policy_path('emit_metric_caller_id.xml', sample_folder)
    emit_metric_policy_xml = Path(emit_metric_policy_path).read_text(encoding='utf-8')

    entraid_api_path = 'appid-cost-demo'
    entraid_cost_demo_get = GET_APIOperation2('get-status', 'Get Status', '/get', 'Get Status')

    apis.append(
        API(
            f'{api_prefix}appid-tracking-api',
            'Cost Tracking by App ID',
            entraid_api_path,
            'API for demonstrating cost tracking by Entra ID application',
            policyXml = emit_metric_policy_xml,
            operations = [entraid_cost_demo_get],
            tags = ['costing', 'emit-metric', 'entra-appid'],
            subscriptionRequired = True,
            serviceUrl = 'https://httpbin.org'
        )
    )


# AI Gateway token tracking API (caller identity + diagnostic-log-based token tracking)
if enable_token_tracking:
    token_metric_policy_path = utils.determine_policy_path('emit_metric_caller_tokens.xml', sample_folder)
    token_metric_policy_xml = Path(token_metric_policy_path).read_text(encoding='utf-8')
    # Strip stream_options enforcement block if force_stream_include_usage is False
    if not force_stream_include_usage:
        token_metric_policy_xml = re.sub(
            r'\s*<!-- \[STREAM-USAGE-ENFORCEMENT-BEGIN\] -->.*?<!-- \[STREAM-USAGE-ENFORCEMENT-END\] -->',
            '',
            token_metric_policy_xml,
            flags=re.DOTALL
        )

    # Operation-level policy that mocks an Azure OpenAI response with a usage object
    # so the gateway diagnostic logs can capture token data for the sample.
    mock_ai_policy_path = utils.determine_policy_path('mock-ai-response.xml', sample_folder)
    mock_ai_policy_xml = Path(mock_ai_policy_path).read_text(encoding='utf-8')

    token_api_path = 'token-cost-demo'
    token_cost_demo_get = GET_APIOperation2('get-status', 'Get Status', '/get', 'Get Status', policyXml=mock_ai_policy_xml)

    apis.append(
        API(
            f'{api_prefix}token-tracking-api',
            'AI Gateway Token Tracking',
            token_api_path,
            'API for demonstrating per-caller token/PTU tracking (AI Gateway pattern)',
            policyXml = token_metric_policy_xml,
            operations = [token_cost_demo_get],
            tags = ['costing', 'emit-metric', 'ai-gateway', 'token-tracking'],
            subscriptionRequired = True,
            serviceUrl = 'https://httpbin.org'
        )
    )

# Azure OpenAI Gateway API (real AOAI backend when enable_foundry = True)
if enable_foundry and enable_token_tracking:
    aoai_operation_policy_path = utils.determine_policy_path('aoai-gateway-operation.xml', sample_folder)
    aoai_operation_policy_xml = Path(aoai_operation_policy_path).read_text(encoding='utf-8')

    aoai_api_path = 'aoai-gateway'
    aoai_chat_post = APIOperation(
        'chat-completion',
        'Chat Completion',
        '/deployments/{deploymentId}/chat/completions',
        HTTP_VERB.POST,
        'Azure OpenAI chat completion (streaming and non-streaming)',
        policyXml = aoai_operation_policy_xml,
        templateParameters = [{'name': 'deploymentId', 'type': 'string', 'required': True}]
    )

    apis.append(
        API(
            f'{api_prefix}aoai-gateway',
            'AOAI Gateway (Cost Tracking)',
            aoai_api_path,
            'Azure OpenAI gateway for demonstrating real token tracking with Foundry',
            policyXml = token_metric_policy_xml,
            operations = [aoai_chat_post],
            tags = ['costing', 'emit-metric', 'ai-gateway', 'aoai', 'foundry'],
            subscriptionRequired = True,
            serviceUrl = 'https://placeholder.openai.azure.com/openai',
            enableLlmLogging = True
        )
    )

# Simulated caller app IDs (for Entra ID tracking)
simulated_callers = [
    {'appid': 'a5846c0e-1111-4000-8000-000000000001', 'name': 'HR Service',         'request_weight': 1.0},
    {'appid': '9e6bfb3f-2222-4000-8000-000000000002', 'name': 'Finance Portal',     'request_weight': 2.5},
    {'appid': 'c3d2e1f0-3333-4000-8000-000000000003', 'name': 'Mobile Gateway',     'request_weight': 0.5},
    {'appid': 'b7a8c9d0-4444-4000-8000-000000000004', 'name': 'Engineering Tools',  'request_weight': 3.0},
    {'appid': 'd4c5e6f7-5555-4000-8000-000000000005', 'name': 'Sales CRM',          'request_weight': 2.0},
    {'appid': 'e8f9a0b1-6666-4000-8000-000000000006', 'name': 'Operations Console', 'request_weight': 1.5}
]

# Define business units
business_units = [
    {'name': 'bu-hr',          'display': 'Business Unit - Human Resources',  'request_weight': 1.0},
    {'name': 'bu-finance',     'display': 'Business Unit - Finance',          'request_weight': 2.5},
    {'name': 'bu-marketing',   'display': 'Business Unit - Marketing',        'request_weight': 0.5},
    {'name': 'bu-engineering', 'display': 'Business Unit - Engineering',      'request_weight': 3.0},
    {'name': 'bu-sales',       'display': 'Business Unit - Sales',            'request_weight': 2.0},
    {'name': 'bu-operations',  'display': 'Business Unit - Operations',       'request_weight': 1.5}
]
print_ok('Notebook initialized')

# Get Azure account information
current_user, current_user_id, tenant_id, subscription_id = get_account_info()

if not subscription_id:
    print_error('Could not determine Azure subscription ID. Run: az login')
    raise SystemExit(1)

# %% [markdown]
# ### 2/14: 🚀 Deploy Infrastructure and APIs
#
# Creates the bicep deployment into the previously-specified resource group. A bicep parameters, `params.json`, file will be created prior to execution.

# %%
from azure_cost import get_apim_sku_pricing, get_model_pricing

# Derive pricing from the deployed APIM SKU for workbook defaults
sku_pricing = get_apim_sku_pricing(apim_sku)

# Derive per-token pricing for the AI model
model_pricing = get_model_pricing(ai_model_name)

# Build the bicep parameters
bicep_parameters = {
    'location'              : {'value': rg_location},
    'costExportFrequency'   : {'value': cost_export_frequency},
    'index'                 : {'value': index},
    'apis'                  : {'value': [api.to_dict() for api in apis]},
    'businessUnits'         : {'value': [{'name': bu['name'], 'displayName': bu['display']} for bu in business_units]},
    'policyFragments'       : {'value': [pf.to_dict() for pf in pfs]},
    'apimSkuDisplayName'    : {'value': apim_sku.value},
    'baseMonthlyCost'       : {'value': str(sku_pricing.base_monthly_cost)},
    'perKRate'              : {'value': str(sku_pricing.per_k_rate)},
    'promptTokenRate'       : {'value': str(model_pricing.prompt_rate_per_k)},
    'completionTokenRate'   : {'value': str(model_pricing.completion_rate_per_k)},
    'enableFoundry'         : {'value': enable_foundry},
    'aiModels'              : {'value': ai_models}
}

# Deploy the sample
output = nb_helper.deploy_sample(bicep_parameters)

if output.success:
    # Extract deployment outputs
    apim_name                      = output.get('apimServiceName', 'APIM Service Name')
    apim_gateway_url               = output.get('apimResourceGatewayURL', 'APIM API Gateway URL')
    app_insights_name              = output.get('applicationInsightsName', 'Application Insights Name')
    app_insights_connection_string = output.get('applicationInsightsConnectionString', '')
    log_analytics_name             = output.get('logAnalyticsWorkspaceName', 'Log Analytics Workspace Name')
    storage_account_name           = output.get('storageAccountName', 'Storage Account Name')
    workbook_name                  = output.get('workbookName', 'Workbook Name')
    workbook_id                    = output.get('workbookId', '')
    cost_export_name               = f'apim-cost-export-{index}-{rg_name}'

    # Extract BU subscription keys (scoped to cost-tracking API)
    subscription_keys_output       = output.getJson('subscriptionKeys', 'Subscription Keys', secure=True)

    # Foundry outputs (empty strings when enableFoundry = False)
    aoai_endpoint                  = output.get('aoaiEndpoint', '')
    aoai_name                      = output.get('aoaiName', '')
    model_deployment_name          = output.get('modelDeploymentName', '')
    model_deployment_names         = output.getJson('modelDeploymentNames', 'Model Deployment Names') or []
    foundry_hub_name               = output.get('foundryHubName', '')
    foundry_project_name           = output.get('foundryProjectName', '')

    if enable_foundry and aoai_endpoint:
        print_ok(f'Foundry deployed: {foundry_hub_name} / {foundry_project_name}')
        print_val('AOAI Endpoint', aoai_endpoint)
        print_val('Model Deployments', ', '.join(model_deployment_names) if model_deployment_names else model_deployment_name)

    # Per-API subscription keys are retrieved on demand via
    # get_apim_subscription_key() (RBAC-controlled ARM listSecrets).

    # Map APIM subscription keys to business units
    subscriptions = {}
    if subscription_keys_output:
        for bu in business_units:
            sub_id = bu['name']
            primary_key = next((item['primaryKey'] for item in subscription_keys_output if item['name'] == sub_id), None)

            subscriptions[sub_id] = {
                'display_name': bu['display'],
                'primary_key': primary_key,
                'request_weight': bu.get('request_weight', 1.0)
            }

    print_ok('Deployment completed successfully')
else:
    print_error('Deployment failed!')
    raise SystemExit(1)

# %% [markdown]
# ### 3/14: 📊 Cost Analysis & Sample Kusto Queries
#
# #### Cost Allocation Model
#
# | Component | Formula |
# |---|---|
# | **Base Cost** | Monthly platform cost for the APIM SKU |
# | **Base Cost Share** | `Base Monthly Cost × (BU Requests ÷ Total Requests)` |
# | **Variable Cost** | `BU Requests × (Rate per 1K ÷ 1000)` |
# | **Total Allocated** | `Base Cost Share + Variable Cost` |
#
# The next cell derives pricing from the deployed APIM SKU via `azure_cost.get_apim_sku_pricing()`. For the latest pricing, see the [Azure API Management pricing page](https://azure.microsoft.com/pricing/details/api-management/).

# %%
from azure_cost import get_apim_sku_pricing, get_model_pricing, APIM_PRICING_AS_OF, APIM_PRICING_URL, AOAI_PRICING_AS_OF, AOAI_PRICING_URL

# Derive pricing from the deployed APIM SKU
sku_pricing         = get_apim_sku_pricing(apim_sku)
base_monthly_cost   = sku_pricing.base_monthly_cost
per_k_rate          = sku_pricing.per_k_rate
included_requests_k = sku_pricing.included_requests_k

# Derive per-token pricing for the primary AI model (used as workbook defaults)
model_pricing       = get_model_pricing(ai_model_name)
prompt_rate_per_k   = model_pricing.prompt_rate_per_k
completion_rate_per_k = model_pricing.completion_rate_per_k

print_val('APIM SKU', apim_sku.value)
print_val('Base monthly cost', f'${base_monthly_cost:.2f}')
print_val('Overage rate per 1K', f'${per_k_rate}')
print_val('Included requests (K)', f'{included_requests_k:,.0f}')
print_info(f'APIM pricing as of {APIM_PRICING_AS_OF}: {APIM_PRICING_URL}', True)
print()

# Per-model pricing table
print_info('AI model pricing (per 1K tokens)')
pricing_table = TableLogger()
pricing_table.header(
    Column('Model'),
    Column('Prompt $/1K', align='>'),
    Column('Completion $/1K', align='>')
)
pricing_rows = []
for m in model_test_matrix:
    mp = get_model_pricing(m)
    pricing_rows.append([m, f'${mp.prompt_rate_per_k:.5f}', f'${mp.completion_rate_per_k:.5f}'])
pricing_table.populate(pricing_rows)
pricing_table.print()

print_info(f'Azure OpenAI pricing as of {AOAI_PRICING_AS_OF}: {AOAI_PRICING_URL}', True)

# %% [markdown]
# ### 4/14: [Setup] 🔧 Configure Cost Management Export
#
# Automatically set up cost data export to the storage account.

# %%
import json
import tempfile
from datetime import datetime, timedelta, timezone
from pathlib import Path

from azure_resources import run

if 'storage_account_name' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)

print_info('Configuring automated Cost Management export (managed identity)...')

# Get storage account resource ID
storage_account_id = (
    f'/subscriptions/{subscription_id}'
    f'/resourceGroups/{rg_name}'
    f'/providers/Microsoft.Storage/storageAccounts/{storage_account_name}'
)

# Export scope and name
export_scope = f'/subscriptions/{subscription_id}'
api_version = '2025-03-01'

# Verify that the Microsoft.CostManagementExports resource provider is registered
rp_check = run('az provider show --namespace Microsoft.CostManagementExports --query registrationState -o tsv')
if not rp_check.success or rp_check.text.strip() != 'Registered':
    print_error('The Microsoft.CostManagementExports resource provider is not registered.')
    print_info('Run the setup script to register all required providers: setup/local_setup.py')
    raise SystemExit(1)

# Check if export already exists
existing_export = run(
    f'az rest --method GET '
    f'--url "{export_scope}/providers/Microsoft.CostManagement/exports/{cost_export_name}'
    f'?api-version={api_version}" -o json'
)

if existing_export.success:
    print_warning(f'Cost export "{cost_export_name}" already exists - recreating...')
    run(
        f'az rest --method DELETE '
        f'--url "{export_scope}/providers/Microsoft.CostManagement/exports/{cost_export_name}'
        f'?api-version={api_version}"'
    )

# Build recurrence settings
recurrence_map = {'Daily': 'Daily', 'Weekly': 'Weekly', 'Monthly': 'Monthly'}
recurrence = recurrence_map.get(cost_export_frequency, 'Daily')

start_date = (datetime.now(timezone.utc) + timedelta(days=1)).strftime('%Y-%m-%dT00:00:00Z')
end_date = (datetime.now(timezone.utc) + timedelta(days=365)).strftime('%Y-%m-%dT00:00:00Z')

# Build the export body with system-assigned managed identity
export_body = {
    'identity': {
        'type': 'systemAssigned'
    },
    'location': 'global',
    'properties': {
        'definition': {
            'type': 'ActualCost',
            'timeframe': 'MonthToDate',
            'dataSet': {
                'granularity': 'Daily'
            }
        },
        'deliveryInfo': {
            'destination': {
                'type': 'AzureBlob',
                'container': 'cost-exports',
                'rootFolderPath': 'apim-costing',
                'resourceId': storage_account_id
            }
        },
        'schedule': {
            'status': 'Active',
            'recurrence': recurrence,
            'recurrencePeriod': {
                'from': start_date,
                'to': end_date
            }
        },
        'format': 'Csv'
    }
}

print_info('Creating cost export with managed identity...')

# Write body to a temp file for cross-platform compatibility
with tempfile.NamedTemporaryFile(mode='w', suffix='.json', delete=False) as body_file:
    json.dump(export_body, body_file)
    body_file_path = body_file.name

try:
    export_result = run(
        f'az rest --method PUT '
        f'--url "{export_scope}/providers/Microsoft.CostManagement/exports/{cost_export_name}'
        f'?api-version={api_version}" '
        f'--body @{body_file_path} -o json'
    )
finally:
    Path(body_file_path).unlink(missing_ok=True)

if export_result and export_result.success:
    print_ok(f'Cost export created: {cost_export_name}')
    print_val('Export frequency', recurrence)
    print_val('Authentication', 'System-assigned managed identity')
    cost_export_configured = True

    # Extract the managed identity principal ID from the response
    export_data = json.loads(export_result.text)
    principal_id = export_data.get('identity', {}).get('principalId')

    if principal_id:
        print_info('Assigning Storage Blob Data Contributor role to export identity...')

        role_assignment = run(
            f'az role assignment create '
            f'--assignee-object-id {principal_id} '
            f'--assignee-principal-type ServicePrincipal '
            f'--role "Storage Blob Data Contributor" '
            f'--scope {storage_account_id}'
        )

        if role_assignment.success:
            print_ok('Storage Blob Data Contributor role assigned to export identity')
        else:
            print_warning('Could not assign role - you may need to do this manually')
    else:
        print_warning('Could not retrieve export identity principal ID')

    print_info('Cost data will be exported automatically starting tomorrow')
else:
    print_error('Failed to create cost export')
    print_warning('Continuing without cost export - you can configure it manually later')
    cost_export_configured = False

# %% [markdown]
# ### 5/14: [Setup] 📤 Trigger Initial Cost Export
#
# Run the first cost export manually to populate data immediately.

# %%
from azure_resources import run

if 'cost_export_configured' not in locals():
    print_error('Please run the cost export configuration cell first')
    raise SystemExit(1)

if cost_export_configured:
    export_scope = f'/subscriptions/{subscription_id}'
    api_version = '2025-03-01'

    print_info(f'Triggering first cost export run for "{cost_export_name}"...')

    run_result = run(
        f'az rest --method POST '
        f'--url "{export_scope}/providers/Microsoft.CostManagement/exports/{cost_export_name}'
        f'/run?api-version={api_version}"'
    )

    if run_result.success:
        print_ok('Cost export run triggered successfully')
        print_info('Data will appear in the storage container within a few minutes')
    else:
        print_warning('Could not trigger export run - it will run on its next scheduled recurrence')
else:
    print_warning('Cost export was not configured - skipping manual run')

# %% [markdown]
# ### 6/14: [Setup] 🔔 Set Up Budget Alerts per Business Unit
#
# Create Azure Monitor scheduled query alerts that fire when a business unit subscription exceeds a configurable request threshold.
#
# Each alert:
# - Runs a Kusto query every **5 minutes** against the Log Analytics workspace
# - Triggers when a business unit exceeds the threshold in a **1-hour** rolling window
# - Sends notifications via an **Action Group** (email)
#
# > Adjust `alert_threshold` and `alert_email` in the initialization cell to match your requirements.

# %%
import json
import tempfile
from pathlib import Path

from azure_resources import run

if not alert_email:
    print_warning('No alert_email configured - skipping budget alert setup')
    print_info('Set alert_email above to enable budget alerts per business unit')
else:
    print_info('Setting up budget alerts per business unit subscription...')

    # Get Log Analytics workspace resource ID
    workspace_result = run(
        f'az monitor log-analytics workspace show '
        f'--resource-group {rg_name} '
        f'--workspace-name {log_analytics_name} '
        f'--query id -o tsv'
    )
    workspace_id = workspace_result.text.strip()

    # Create an Action Group for alert notifications
    action_group_name = f'ag-apim-cost-alerts-{index}'
    print_info(f'Creating action group: {action_group_name}...')

    ag_result = run(
        f'az monitor action-group create '
        f'--resource-group {rg_name} '
        f'--name {action_group_name} '
        f'--short-name apimcost '
        f'--action email cost-alert-email {alert_email} '
        f'-o json'
    )

    if ag_result.success:
        action_group_id = ag_result.json_data.get('id', '')
        print_ok(f'Action group created: {action_group_name}')
    else:
        print_error(f'Failed to create action group: {ag_result.text}')
        action_group_id = None

    if action_group_id:
        # Load the KQL template from an external file
        kql_path = utils.determine_policy_path('budget-alert-threshold.kql', sample_folder)
        kql_template = Path(kql_path).read_text(encoding='utf-8')

        bu_list = list(subscriptions.keys())
        if not bu_list:
            # Fallback derived from business_units so it stays in sync if the BU list changes
            bu_list = [bu['name'] for bu in business_units]

        print_info(f'Creating alerts for {len(bu_list)} business units (threshold: {alert_threshold} requests/hour)...')

        for bu_name in bu_list:
            alert_name = f'apim-budget-{bu_name}-{index}'

            # Prepend KQL let bindings to parameterise the query
            kusto_query = f"let buName = '{bu_name}';\nlet threshold = {alert_threshold};\n{kql_template}"

            alert_body = {
                'location': rg_location,
                'properties': {
                    'displayName': f'APIM Budget Alert: {bu_name}',
                    'description': f'Fires when {bu_name} exceeds {alert_threshold} API requests per hour',
                    'severity': 2,
                    'enabled': True,
                    'evaluationFrequency': 'PT5M',
                    'windowSize': 'PT1H',
                    'scopes': [workspace_id],
                    'criteria': {
                        'allOf': [
                            {
                                'query': kusto_query,
                                'timeAggregation': 'Count',
                                'operator': 'GreaterThan',
                                'threshold': 0,
                                'failingPeriods': {
                                    'numberOfEvaluationPeriods': 1,
                                    'minFailingPeriodsToAlert': 1
                                }
                            }
                        ]
                    },
                    'actions': {
                        'actionGroups': [action_group_id]
                    }
                }
            }

            alert_id = (
                f'/subscriptions/{subscription_id}'
                f'/resourceGroups/{rg_name}'
                f'/providers/Microsoft.Insights/scheduledQueryRules/{alert_name}'
            )

            # Write body to a temp file to avoid shell quoting issues on Windows
            with tempfile.NamedTemporaryFile(mode='w', suffix='.json', delete=False) as f:
                json.dump(alert_body, f)
                alert_body_path = f.name

            try:
                result = run(
                    f'az rest --method PUT '
                    f'--uri https://management.azure.com{alert_id}?api-version=2023-03-15-preview '
                    f'--body @{alert_body_path}'
                )
            finally:
                Path(alert_body_path).unlink(missing_ok=True)

            if result.success:
                print_ok(f'  Alert created: {alert_name}')
            else:
                print_error(f'  Failed to create alert for {bu_name}: {result.text[:200]}')

        print()
        print_ok('Budget alerts configured!')
        print_val('Action Group', action_group_name)
        print_val('Alert Email', alert_email)
        print_val('Threshold', f'{alert_threshold} requests per hour per BU')
        print_val('Evaluation', 'Every 5 minutes, 1-hour rolling window')

# %% [markdown]
# ### 7/14: [Traffic] 🚀 Generate Sample API Traffic
#
# Generate sample API calls from each business unit subscription to demonstrate cost tracking and allocation.
#
# This will create request logs in Application Insights and Log Analytics that can be used for cost analysis.

# %%
import requests as http_requests

from _helpers import build_session, persist_traffic_source, purge_traffic_source

if 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)

# Always purge any stale `subscription-based-costing` entry from a prior run
# BEFORE deciding whether to regenerate traffic. This keeps the persisted
# JSON honest when run_regular_requests / generate_sample_load are toggled
# off — otherwise the file would still show last run's request counts.
local_data_path = Path(utils.determine_policy_path('bu-request-counts.local.json', sample_folder))
if purge_traffic_source(local_data_path, 'subscription-based-costing'):
    print_info('Removed stale subscription-based-costing entry from bu-request-counts.local.json')

if generate_sample_load and run_regular_requests:
    print_info('Generating sample API traffic...')

    # Determine endpoints, URLs, etc. prior to test execution
    endpoint_url, request_headers, allow_insecure_tls = utils.get_endpoint(deployment, rg_name, apim_gateway_url)

    # Shared HTTP session (reuses TCP+TLS connections across all business units).
    # Auto-retry on transient TLS / connection resets (e.g. SSLEOFError) so a single
    # blip mid-loop doesn't abort the whole traffic-generation run.
    session = build_session(request_headers, allow_insecure_tls, with_retries=True)

    url = f'{endpoint_url}/{api_path}/get'

    # Track request counts per BU so we can print a summary table and persist the
    # ground-truth numbers locally for cross-checking against the Monitor workbook.
    # We record both `planned` (what we asked for) and `requests` (what APIM
    # actually saw, i.e. what backend logs will show). They will only differ
    # if a request fails to reach APIM (network/TLS error not handled by retry).
    bu_request_counts = []

    try:
        # Send requests for each business unit, weighted by its configured request_weight
        for subscription_id_sub, sub_info in subscriptions.items():
            bu_request_count = max(1, int(sample_requests_per_subscription * sub_info.get('request_weight', 1.0)))

            print_info(f'Generating {bu_request_count} requests for {subscription_id_sub}')
            delivered = 0
            for _ in range(bu_request_count):
                try:
                    session.get(url, headers={'api-key': sub_info['primary_key']}, timeout=30)
                    delivered += 1
                except http_requests.RequestException:
                    # Did not reach APIM (or all retries exhausted) -> not in backend logs
                    pass

            bu_request_counts.append({
                'name'        : subscription_id_sub,
                'display_name': sub_info.get('display_name', ''),
                'weight'      : float(sub_info.get('request_weight', 1.0)),
                'planned'     : bu_request_count,
                'requests'    : delivered,
            })
    finally:
        session.close()

    # --- Print the request count table ---
    print()
    print_info('Business Unit Request Summary:')
    print()

    table = TableLogger()
    table.header(
        Column('Business Unit', width=20),
        Column('Display Name', width=40),
        Column('Weight', width=8, align='>'),
        Column('Planned', width=10, align='>'),
        Column('Delivered', width=10, align='>'),
    )
    table.populate([
        [r['name'], r['display_name'], f'{r["weight"]:.1f}', r['planned'], r['requests']]
        for r in bu_request_counts
    ])
    total_planned = sum(r['planned'] for r in bu_request_counts)
    total_requests = sum(r['requests'] for r in bu_request_counts)
    table.total('TOTAL', '', '', total_planned, total_requests)
    table.print()

    # --- Persist the request counts locally (gitignored) ---
    # The *.local.json suffix is excluded via .gitignore. Use this file to validate
    # the numbers shown in the Monitor workbook against the ground-truth values
    # generated by this notebook run. The same file is updated by later AI traffic
    # cells (cells 10 + 11) so it captures both AI and non-AI ground truth.
    # `requests` mirrors what backend logs will show; `planned` is the intended count.
    persist_traffic_source(
        local_data_path,
        sample_folder=sample_folder,
        rg_name=rg_name,
        apim_name=apim_name,
        source_entry={
            'name'             : 'subscription-based-costing',
            'apiName'          : api_path,
            'isAi'             : False,
            'baseRequestsPerBu': sample_requests_per_subscription,
            'plannedRequests'  : total_planned,
            'totalRequests'    : total_requests,
            'businessUnits'    : [{**r, 'isAi': False} for r in bu_request_counts],
        },
    )

    print()
    print_ok(f'Persisted ground-truth request counts to: {local_data_path}')
    print_info('This file is excluded from git via *.local.json. Use it to cross-check workbook results.')
    print_info('AI traffic cells (10/14, 11/14) will append their own trafficSources entries.')

    print()
    print_info('Note: It may take 2-5 minutes for logs to appear in Application Insights and Log Analytics')
elif not run_regular_requests:
    print_info('Regular request generation skipped (run_regular_requests = False)')
else:
    print_info('Sample load generation skipped (generate_sample_load = False)')

# %% [markdown]
# ### 8/14: [Traffic] 🚀 Generate Entra ID Application Traffic
#
# Generate sample API calls simulating different Entra ID applications (via crafted JWT `appid` claims) to demonstrate caller-based cost tracking.
#
# This creates `caller-requests` custom metrics in Application Insights via the `emit-metric` policy.
#
# > **Note:** In a production environment, callers would present real Entra ID tokens. Here we simulate them with minimal JWTs so that the `emit-metric` policy can extract the `appid` claim.

# %%
from azure_resources import get_apim_subscription_key

from _helpers import build_session, make_fake_jwt

if 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)

if enable_entraid_tracking and generate_sample_load and run_regular_requests:
    print_info('Generating sample API traffic with simulated caller app IDs...')

    # Retrieve the per-API subscription key via RBAC-controlled ARM listSecrets
    entraid_subscription_key = get_apim_subscription_key(
        apim_name, rg_name, sid=f'api-{api_prefix}appid-tracking-api'
    )

    if not entraid_subscription_key:
        print_error('Could not retrieve subscription key for the Entra ID tracking API')
        raise SystemExit(1)

    # Determine endpoints, URLs, etc. prior to test execution
    endpoint_url, request_headers, allow_insecure_tls = utils.get_endpoint(deployment, rg_name, apim_gateway_url)

    # Shared HTTP session (reuses TCP+TLS connections across all callers)
    session = build_session(
        request_headers,
        allow_insecure_tls,
        extra_headers={'api-key': entraid_subscription_key},
    )

    url = f'{endpoint_url}/{entraid_api_path}/get'

    try:
        for caller in simulated_callers:
            caller_request_count = max(1, int(sample_requests_per_subscription * caller.get('request_weight', 1.0)))
            fake_jwt = make_fake_jwt(caller['appid'])

            print_info(f'Generating {caller_request_count} requests for {caller["name"]} ({caller["appid"][:12]}...)')
            for _ in range(caller_request_count):
                session.get(url, headers={'Authorization': f'Bearer {fake_jwt}'}, timeout=30)
    finally:
        session.close()

    # Display a summary table of simulated callers
    print()
    print_info('Simulated Caller Summary:')
    print()
    rows = []
    for caller in simulated_callers:
        req_count = max(1, int(sample_requests_per_subscription * caller.get('request_weight', 1.0)))
        rows.append([caller['appid'], caller['name'], f'{caller["request_weight"]:.1f}', req_count])
    total_reqs = sum(max(1, int(sample_requests_per_subscription * c.get('request_weight', 1.0))) for c in simulated_callers)

    table = TableLogger()
    table.header(Column('App ID'), Column('Caller Name'), Column('Weight', align='>'), Column('Requests', align='>'))
    table.populate(rows)
    table.total('TOTAL', '', '', total_reqs)
    table.print()

    print()
    print_info('Note: Custom metrics typically take 5-10 minutes to appear in Application Insights')
elif not enable_entraid_tracking:
    print_info('Entra ID tracking disabled (enable_entraid_tracking = False)')
elif not run_regular_requests:
    print_info('Regular request generation skipped (run_regular_requests = False)')
else:
    print_info('Sample load generation skipped (generate_sample_load = False)')

# %% [markdown]
# ### 9/14: [Traffic] 🔑 Test with a Real JWT Token (Optional)
#
# When `use_real_jwt = True` is set in the configuration above, this cell acquires a real Entra ID token using the
# **client credentials** flow (OAuth 2.0) and sends requests through the `emit-metric` API.
#
# This validates the end-to-end flow:
#
# 1. An Entra ID app registration presents a JWT with a real `appid` claim
# 2. The `emit-metric` APIM policy extracts the `appid` from the token
# 3. A `caller-requests` custom metric is emitted with the real caller ID
#
# > **Prerequisites:** Create an [App Registration](https://learn.microsoft.com/entra/identity-platform/quickstart-register-app)
# > and generate a client secret. No API permissions are required - the `emit-metric` policy only reads the `appid` claim from the JWT.

# %%
import base64
import json
import time

import requests as http_requests
from azure_resources import get_apim_subscription_key

from _helpers import build_session

if not run_regular_requests:
    print_info('Regular request generation skipped (run_regular_requests = False)')
elif not use_real_jwt:
    print_info('Real JWT testing is disabled (use_real_jwt = False)')
    print_info('To enable, set use_real_jwt = True and provide client credentials in the root .env file.')
elif not all([real_jwt_tenant_id, real_jwt_client_id, real_jwt_client_secret]):
    print_error('Missing credentials: set COSTING_JWT_TENANT_ID, COSTING_JWT_CLIENT_ID, and COSTING_JWT_CLIENT_SECRET in the root .env file')
elif 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)
else:
    # Acquire a token using the client credentials flow
    token_url = f'https://login.microsoftonline.com/{real_jwt_tenant_id}/oauth2/v2.0/token'
    token_payload = {
        'grant_type': 'client_credentials',
        'client_id': real_jwt_client_id,
        'client_secret': real_jwt_client_secret,
        'scope': f'api://{real_jwt_client_id}/.default'
    }

    print_info('Acquiring token from Microsoft Identity Platform...')
    token_response = http_requests.post(token_url, data=token_payload, timeout=30)

    if token_response.status_code != 200:
        print_error(f'Token acquisition failed ({token_response.status_code}): {token_response.text[:300]}')
    else:
        access_token = token_response.json().get('access_token', '')
        payload_part = access_token.split('.')[1]
        payload_part += '=' * (4 - len(payload_part) % 4)  # pad base64
        claims = json.loads(base64.urlsafe_b64decode(payload_part))
        real_appid = claims.get('appid', claims.get('azp', 'unknown'))

        print()
        print_info('Token Details:')
        print(f'  {"App ID (appid)":<25} {real_appid}')
        print(f'  {"Tenant ID (tid)":<25} {claims.get("tid", "unknown")}')
        print(f'  {"Token type":<25} {claims.get("typ", claims.get("token_type", "unknown"))}')
        print()

        # Send requests with the real token
        real_jwt_request_count = 10  # Small number for testing

        endpoint_url, request_headers, allow_insecure_tls = utils.get_endpoint(deployment, rg_name, apim_gateway_url)

        # Retrieve the per-API subscription key via RBAC-controlled ARM listSecrets
        entraid_subscription_key = get_apim_subscription_key(
            apim_name, rg_name, sid=f'api-{api_prefix}appid-tracking-api'
        )

        if not entraid_subscription_key:
            print_error('Could not retrieve subscription key for the Entra ID tracking API')
            raise SystemExit(1)

        # Shared HTTP session (reuses TCP+TLS connections)
        session = build_session(
            request_headers,
            allow_insecure_tls,
            extra_headers={
                'api-key'      : entraid_subscription_key,
                'Authorization': f'Bearer {access_token}',
            },
        )

        url = f'{endpoint_url}/{entraid_api_path}/get'

        try:
            print_info(f'Sending {real_jwt_request_count} requests with real JWT (appid: {real_appid[:12]}...)')
            for i in range(real_jwt_request_count):
                session.get(url, timeout=30)
                if i < real_jwt_request_count - 1:
                    time.sleep(0.1)
        finally:
            session.close()

        print()
        print_ok(f'Sent {real_jwt_request_count} requests with real Entra ID token')

# %% [markdown]
# ### 10/14: [Traffic] 🤖 Real AOAI Interactions (Foundry)
#
# When `enable_foundry = True` (the default), the Bicep deployment creates an Azure AI Services account with a model deployment and
# an APIM backend with managed identity authentication. This cell sends **real** Azure OpenAI chat completion requests
# through the APIM gateway to demonstrate accurate token tracking, and the mock token-tracking simulation in the next cell is **skipped** so the AI traffic numbers reflect only real Foundry calls.
#
# Two interaction modes are demonstrated:
# 1. **Non-streaming** - Standard JSON response with a `usage` object
# 2. **Streaming (SSE)** - Server-sent events with `stream_options.include_usage = true` so the final chunk contains token counts
#
# > **Note:** The outbound policy buffers streaming responses to extract token usage. In production, consider the built-in
# > `azure-openai-emit-token-metric` policy for zero-impact streaming. See the README for details.
#
# > **Double-counting warning:** Do NOT enable both the custom `emit-metric` token tracking and the built-in
# > `azure-openai-emit-token-metric` policy simultaneously. Each emits its own metrics; combining them
# > produces duplicate counts.

# %%
from pathlib import Path

import requests as http_requests
from azure_resources import get_apim_subscription_key
from console import Column, TableLogger, print_error, print_info, print_ok, print_warning, print_val

from _helpers import build_session, make_fake_jwt, persist_traffic_source, purge_traffic_source

# Always purge any stale `ai-gateway-aoai` entry from a prior run BEFORE
# deciding whether to regenerate AI traffic. Keeps the persisted JSON honest
# when run_ai_requests / enable_foundry / enable_token_tracking are toggled
# off — otherwise the file would still show last run's request counts.
local_data_path = Path(utils.determine_policy_path('bu-request-counts.local.json', sample_folder))
if purge_traffic_source(local_data_path, 'ai-gateway-aoai'):
    print_info('Removed stale ai-gateway-aoai entry from bu-request-counts.local.json')

if not run_ai_requests:
    print_info('AI request generation skipped (run_ai_requests = False)')
elif not enable_foundry:
    print_info('Foundry is disabled (enable_foundry = False) - skipping real AOAI interactions')
    print_info('Set enable_foundry = True in the init cell to deploy Foundry and use real AOAI responses')
elif not enable_token_tracking:
    print_info('Token tracking disabled - skipping real AOAI interactions')
elif 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)
elif not aoai_endpoint:
    print_error('AOAI endpoint not available - deployment may have failed')
    raise SystemExit(1)
else:
    print_info('Sending real Azure OpenAI requests through APIM gateway...')
    print_val('AOAI Endpoint', aoai_endpoint)
    print_val('Models', ', '.join(model_test_matrix.keys()))
    print()

    # Sanity-check that the AOAI gateway API is properly subscribed before we
    # send traffic. The returned key is not attached to outgoing requests --
    # the per-BU loop below uses `bu-*` subscription keys so every AOAI request
    # is attributed to a business unit and the workbook tiles reconcile cleanly.
    aoai_subscription_key = get_apim_subscription_key(
        apim_name, rg_name, sid=f'api-{api_prefix}aoai-gateway'
    )

    if not aoai_subscription_key:
        print_error('Could not retrieve subscription key for the AOAI gateway API')
        raise SystemExit(1)

    endpoint_url, request_headers, allow_insecure_tls = utils.get_endpoint(deployment, rg_name, apim_gateway_url)

    # NOTE: No `api-key` is set on the session itself. Each request in the
    # multi-BU loop overrides the api-key per call to a `bu-*` subscription
    # key so every AOAI request is attributed to a business unit.
    session = build_session(
        request_headers,
        allow_insecure_tls,
        extra_headers={'Content-Type': 'application/json'},
    )

    # Request bodies reused by the multi-BU traffic loop. Both delivery modes
    # are exercised inside the loop below.
    chat_body = {
        'messages': [
            {'role': 'system', 'content': 'You are a helpful assistant. Keep responses brief.'},
            {'role': 'user', 'content': 'What is Azure API Management in one sentence?'}
        ],
        'max_completion_tokens': 100  # gpt-4o and later models require max_completion_tokens instead of max_tokens
    }
    stream_body = {
        **chat_body,
        'messages': [
            {'role': 'system', 'content': 'You are a helpful assistant. Keep responses brief.'},
            {'role': 'user', 'content': 'What are the benefits of using APIM as an AI Gateway? List three.'}
        ],
        'stream': True,
        'stream_options': {'include_usage': True}
    }

    # --- Multi-BU traffic generation (sequential per BU per model) ---
    print_info('Generating multi-BU AOAI traffic for cost tracking (per model)...')

    # Per-model request counters for the summary table printed at the end of this cell.
    # `delivered` (the counter we increment on a successful HTTP response) is what
    # backend logs (ApiManagementGatewayLogs / ApiManagementGatewayLlmLog) will show.
    model_request_counts = {m: {'non_streaming': 0, 'streaming': 0} for m in model_test_matrix}

    # Per-BU x per-model request counters so we can compare against the AI Gateway
    # workbook tab's "Token Counts by Business Unit & Delivery Mode" table
    bu_model_counts: dict[tuple[str, str], dict[str, int]] = {}

    # Per-BU x per-model planned counters so the persisted JSON can show the
    # difference between intended traffic and what APIM actually saw.
    bu_model_planned: dict[tuple[str, str], dict[str, int]] = {}

    for model_name, cfg in model_test_matrix.items():
        base_requests = cfg['requests_per_caller']
        model_chat_url = f'{endpoint_url}/{aoai_api_path}/deployments/{model_name}/chat/completions'
        print()
        print_info(f'-> Model: {model_name} (base {base_requests} requests per BU, scaled by request_weight)')

        for bu_index, (bu_name, bu_info) in enumerate(subscriptions.items()):
            # Pick a caller (round-robin) so each BU gets a deterministic appid
            # in the gateway logs. Works whether there are fewer or more callers
            # than business units.
            caller = simulated_callers[bu_index % len(simulated_callers)]
            caller_jwt = make_fake_jwt(caller['appid'])
            caller_headers = dict(session.headers)
            caller_headers['Authorization'] = f'Bearer {caller_jwt}'
            # Use the BU's subscription key so the AI Gateway workbook tab
            # shows token consumption broken down by business unit.
            caller_headers['api-key'] = bu_info['primary_key']

            # Scale per-BU traffic by request_weight so heavier BUs (e.g. finance)
            # produce proportionally more tokens than lighter ones (e.g. mobile).
            bu_request_count = max(1, int(base_requests * bu_info.get('request_weight', 1.0)))

            planned_streaming = 0
            planned_non_streaming = 0
            streaming_count = 0
            non_streaming_count = 0
            # If a request hangs/times out, give up on the rest of this BU's
            # requests for this model rather than incurring repeated multi-second
            # timeouts. The first request after a fresh deployment may incur a
            # cold-start delay; the per-call timeouts below are sized accordingly.
            bail_out = False

            for j in range(bu_request_count):
                if bail_out:
                    break
                # Alternate between streaming and non-streaming so the workbook
                # Streaming vs Non-Streaming tab shows both delivery modes per BU
                use_streaming = (j % 2 == 1)
                if use_streaming:
                    planned_streaming += 1
                else:
                    planned_non_streaming += 1
                body = stream_body if use_streaming else chat_body
                try:
                    r = session.post(
                        model_chat_url,
                        json=body,
                        headers=caller_headers,
                        timeout=45 if use_streaming else 30,
                        stream=use_streaming
                    )
                    if use_streaming and r.status_code == 200:
                        # Drain the SSE stream so the connection completes and
                        # the final chunk (with usage) is logged by APIM
                        for _ in r.iter_lines(decode_unicode=True):
                            pass
                except http_requests.Timeout:
                    print_warning(f'  Timeout for {bu_name} on {model_name} (request {j + 1}/{bu_request_count}); skipping remaining requests for this BU')
                    bail_out = True
                    # Did not receive an HTTP response -> won't show in backend logs
                    continue
                except http_requests.RequestException:
                    # Did not receive an HTTP response -> won't show in backend logs
                    continue

                # Only count requests where APIM returned a response (any status).
                # 4xx/5xx are still logged in ApiManagementGatewayLogs and are valid
                # ground-truth data points to compare against the workbook.
                if use_streaming:
                    streaming_count += 1
                else:
                    non_streaming_count += 1

            model_request_counts[model_name]['streaming'] += streaming_count
            model_request_counts[model_name]['non_streaming'] += non_streaming_count
            bu_model_counts[(bu_name, model_name)] = {
                'non_streaming': non_streaming_count,
                'streaming'    : streaming_count,
            }
            bu_model_planned[(bu_name, model_name)] = {
                'non_streaming': planned_non_streaming,
                'streaming'    : planned_streaming,
            }
            print_ok(
                f'  Sent {bu_request_count} requests for {bu_name} as {caller["name"]}'
                f' ({caller["appid"][:12]}...) [{non_streaming_count} non-streaming,'
                f' {streaming_count} streaming]'
            )

    # --- Per-model request count summary ---
    print()
    print_info('Requests per model')
    summary_table = TableLogger()
    summary_table.header(
        Column('Model'),
        Column('Non-streaming', align='>'),
        Column('Streaming', align='>'),
        Column('Total', align='>')
    )
    summary_rows = []
    grand_ns = grand_s = 0
    for m, counts in model_request_counts.items():
        total = counts['non_streaming'] + counts['streaming']
        summary_rows.append([m, counts['non_streaming'], counts['streaming'], total])
        grand_ns += counts['non_streaming']
        grand_s += counts['streaming']
    summary_table.populate(summary_rows)
    summary_table.total('GRAND TOTAL', grand_ns, grand_s, grand_ns + grand_s)
    summary_table.print()

    # --- Per-BU x per-model request count summary ---
    # Mirrors the AI Gateway workbook tab's 'Token Counts by Business Unit &
    # Delivery Mode' table so you can cross-check notebook output against the
    # Azure Monitor workbook after logs land in Log Analytics.
    print()
    print_info('Requests by business unit and model')
    bu_model_table = TableLogger()
    bu_model_table.header(
        Column('Business Unit'),
        Column('Model'),
        Column('Non-streaming', align='>'),
        Column('Streaming', align='>'),
        Column('Total', align='>')
    )
    bu_model_rows = []
    bu_grand_ns = bu_grand_s = 0
    for (bu, m) in sorted(bu_model_counts.keys()):
        counts = bu_model_counts[(bu, m)]
        total = counts['non_streaming'] + counts['streaming']
        bu_model_rows.append([bu, m, counts['non_streaming'], counts['streaming'], total])
        bu_grand_ns += counts['non_streaming']
        bu_grand_s += counts['streaming']
    bu_model_table.populate(bu_model_rows)
    bu_model_table.total('GRAND TOTAL', '', bu_grand_ns, bu_grand_s, bu_grand_ns + bu_grand_s)
    bu_model_table.print()

    total_aoai_requests = grand_ns + grand_s
    print()
    print_ok(f'Total real AOAI requests: {total_aoai_requests}')
    print_info('Each request emits a caller-requests metric entry')
    print_info('Token counts are captured via the APIM diagnostic setting (ApiManagementGatewayLlmLog)')
    print_info('Note: Custom metrics typically take 5-10 minutes to appear in Application Insights')

    session.close()

    # --- Persist AI Gateway request counts to the shared local JSON file ---
    # Mirrors the BU-level breakdown for the AI Gateway tab so it can be
    # cross-checked against the workbook's 'AI Requests Received' tile and
    # 'Token Counts by Business Unit & Delivery Mode' table.
    # `requests`/`nonStreaming`/`streaming` are delivered counts (what APIM
    # actually saw); `planned` mirrors the intended traffic for diff visibility.
    ai_bu_rollup: dict[str, dict] = {}
    for (bu, m), counts in bu_model_counts.items():
        bu_info_local = subscriptions.get(bu, {})
        planned = bu_model_planned.get((bu, m), {'non_streaming': 0, 'streaming': 0})
        entry = ai_bu_rollup.setdefault(bu, {
            'name'        : bu,
            'display_name': bu_info_local.get('display_name', ''),
            'weight'      : float(bu_info_local.get('request_weight', 1.0)),
            'planned'     : 0,
            'requests'    : 0,
            'isAi'        : True,
            'byModel'     : [],
        })
        model_total = counts['non_streaming'] + counts['streaming']
        planned_total = planned['non_streaming'] + planned['streaming']
        entry['planned'] += planned_total
        entry['requests'] += model_total
        entry['byModel'].append({
            'model'       : m,
            'plannedNonStreaming': planned['non_streaming'],
            'plannedStreaming'   : planned['streaming'],
            'nonStreaming': counts['non_streaming'],
            'streaming'   : counts['streaming'],
            'total'       : model_total,
        })

    total_aoai_planned = sum(p['non_streaming'] + p['streaming'] for p in bu_model_planned.values())
    persist_traffic_source(
        local_data_path,
        sample_folder=sample_folder,
        rg_name=rg_name,
        apim_name=apim_name,
        source_entry={
            'name'           : 'ai-gateway-aoai',
            'apiName'        : aoai_api_path,
            'isAi'           : True,
            'plannedRequests': total_aoai_planned,
            'totalRequests'  : total_aoai_requests,
            'businessUnits'  : list(ai_bu_rollup.values()),
        },
    )

    print()
    print_ok(f'Persisted AI Gateway request counts to: {local_data_path}')

# %% [markdown]
# ### 11/14: [Traffic] 🤖 AI Gateway: Token Consumption per Client (mock)
#
# This cell runs **only when `enable_foundry = False`** so it cannot pollute the AI traffic numbers when real Foundry calls are being made in cell 10. It demonstrates how to track **requests per calling application** using the `emit-metric`
# policy against a **mock** AOAI backend (httpbin) that returns a realistic chat-completion response. The policy emits `caller-requests` custom metrics with `CallerId`, `API`, and `Operation` dimensions.
# Token-level data (prompt, completion, total tokens) is captured separately via the APIM diagnostic setting
# (`ApiManagementGatewayLlmLog`) — no response buffering needed at the policy level.
#
# > **Why gate on `enable_foundry`?** When Foundry is deployed (`enable_foundry = True`), cell 10 already exercises caller attribution (via fake JWT `appid` claims) on real AOAI traffic. Running this mock simulation in addition could be confusing with AI traffic in workbook tiles like *AI APIM Requests* and add ~210 phantom requests to the totals.
#
# > **Note:** To use this with a real backend, point the API's `serviceUrl` to your Azure OpenAI deployment.
# > Token counts are automatically written to `ApiManagementGatewayLlmLog` by the diagnostic setting.
#
# | Dimension | Description |
# |---|---|
# | **CallerId** | Entra ID application (from JWT `appid`/`azp` claim) |
# | **API** | APIM API name |
# | **Operation** | APIM operation name |

# %%
from pathlib import Path

import requests as http_requests
from azure_resources import get_apim_subscription_key

from _helpers import build_session, make_fake_jwt, persist_traffic_source, purge_traffic_source

# Always purge any stale `ai-gateway-token-tracking` entry from a prior run
# BEFORE deciding whether to regenerate token-tracking traffic. Keeps the
# persisted JSON honest when run_ai_requests / enable_token_tracking are
# toggled off, or when enable_foundry causes this cell to short-circuit.
local_data_path = Path(utils.determine_policy_path('bu-request-counts.local.json', sample_folder))
if purge_traffic_source(local_data_path, 'ai-gateway-token-tracking'):
    print_info('Removed stale ai-gateway-token-tracking entry from bu-request-counts.local.json')

if not run_ai_requests:
    print_info('AI request generation skipped (run_ai_requests = False)')
elif not enable_token_tracking:
    print_info('Token tracking disabled (enable_token_tracking = False)')
elif enable_foundry:
    # Real Foundry traffic in cell 10 already covers caller-attribution. Running
    # this mock loop in addition would inflate AI traffic counts in the workbook.
    print_info('enable_foundry = True - skipping mock token-tracking traffic')
    print_info('Cell 10 sends real AOAI traffic with caller attribution; this mock cell could be confusing then.')
    print_info('Set enable_foundry = False to use the mock httpbin AOAI backend instead.')
elif 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)
else:
    # --- Generate token-tracking traffic ---
    print_info('Generating AI Gateway traffic with simulated callers...')
    print_info('The emit-metric policy will emit caller-requests metrics per caller identity')
    print()

    # Retrieve the per-API subscription key via RBAC-controlled ARM listSecrets
    token_subscription_key = get_apim_subscription_key(
        apim_name, rg_name, sid=f'api-{api_prefix}token-tracking-api'
    )

    if not token_subscription_key:
        print_error('Could not retrieve subscription key for the token-tracking API')
        raise SystemExit(1)

    endpoint_url, request_headers, allow_insecure_tls = utils.get_endpoint(deployment, rg_name, apim_gateway_url)

    token_requests_per_caller = 20  # Fewer requests needed since each emits 3 metric entries

    # Shared HTTP session (reuses TCP+TLS connections across all callers)
    session = build_session(
        request_headers,
        allow_insecure_tls,
        extra_headers={'api-key': token_subscription_key},
    )

    url = f'{endpoint_url}/{token_api_path}/get'

    # Track delivered (got an HTTP response from APIM) and planned counts per
    # caller so the persisted JSON mirrors what backend logs will show.
    caller_delivered: dict[str, int] = {}
    caller_planned: dict[str, int] = {}

    try:
        for caller in simulated_callers:
            caller_request_count = max(1, int(token_requests_per_caller * caller.get('request_weight', 1.0)))
            fake_jwt = make_fake_jwt(caller['appid'])
            caller_planned[caller['appid']] = caller_request_count

            print_info(f'Generating {caller_request_count} requests for {caller["name"]} ({caller["appid"][:12]}...)')
            delivered = 0
            for _ in range(caller_request_count):
                try:
                    session.get(url, headers={'Authorization': f'Bearer {fake_jwt}'}, timeout=30)
                    delivered += 1
                except http_requests.RequestException:
                    # Did not reach APIM -> not in backend logs
                    pass
            caller_delivered[caller['appid']] = delivered
    finally:
        session.close()

    # Display summary table
    print()
    print_info('AI Gateway Token Traffic Summary:')
    print()
    rows = []
    for caller in simulated_callers:
        planned = caller_planned.get(caller['appid'], 0)
        delivered = caller_delivered.get(caller['appid'], 0)
        rows.append([caller['appid'], caller['name'], f'{caller["request_weight"]:.1f}', planned, delivered, '~10-700'])
    total_planned = sum(caller_planned.values())
    total_reqs = sum(caller_delivered.values())

    table = TableLogger()
    table.header(
        Column('App ID'), Column('Caller Name'), Column('Weight', align='>'),
        Column('Planned', align='>'), Column('Delivered', align='>'), Column('~Tokens/Req', align='>')
    )
    table.populate(rows)
    table.total('TOTAL', '', '', total_planned, total_reqs, '')
    table.print()
    print()
    print_info(f'Expected caller-requests metric entries: ~{total_reqs}')
    print_info('Note: Custom metrics typically take 5-10 minutes to appear in Application Insights')

    print_info('Verification of caller-requests ingestion runs once in step 13/14 (Verify Metric Ingestion)')
    print_info('Token-level data is available in ApiManagementGatewayLlmLog via the APIM diagnostic setting')
    print_info('See bu-token-usage.kql for a query that joins request logs with token counts')

    # --- Persist token-tracking request counts to the shared local JSON file ---
    # Token-tracking traffic is caller-attributed (no bu-* subscription key) so it
    # records a `callers` array instead of `businessUnits`. It does NOT appear in
    # the AI Gateway workbook tab's BU breakdown but DOES count toward 'AI APIM
    # Requests' and 'Total APIM Requests' tiles.
    # `requests` mirrors what backend logs will show; `planned` is the intended count.
    callers_persisted = []
    for caller in simulated_callers:
        callers_persisted.append({
            'appid'   : caller['appid'],
            'name'    : caller['name'],
            'weight'  : float(caller.get('request_weight', 1.0)),
            'planned' : caller_planned.get(caller['appid'], 0),
            'requests': caller_delivered.get(caller['appid'], 0),
            'isAi'    : True,
        })

    persist_traffic_source(
        local_data_path,
        sample_folder=sample_folder,
        rg_name=rg_name,
        apim_name=apim_name,
        source_entry={
            'name'           : 'ai-gateway-token-tracking',
            'apiName'        : token_api_path,
            'isAi'           : True,
            'plannedRequests': total_planned,
            'totalRequests'  : total_reqs,
            'callers'        : callers_persisted,
        },
    )

    print()
    print_ok(f'Persisted token-tracking request counts to: {local_data_path}')

# %% [markdown]
# ### 12/14: [Verify] 🔍 Verify Log Ingestion
#
# Waits for diagnostic logs to arrive in Log Analytics. The pipeline has had several minutes of warm-up across the preceding traffic cells, so the first poll typically succeeds.

# %%
from pathlib import Path

if 'log_analytics_name' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)

print_info('Waiting for APIM logs to arrive in Log Analytics...')
print()
print_val('Workspace', log_analytics_name)

# Build the workspace resource ID for the ARM query endpoint
workspace_resource_id = (
    f'/subscriptions/{subscription_id}'
    f'/resourceGroups/{rg_name}'
    f'/providers/Microsoft.OperationalInsights/workspaces/{log_analytics_name}'
)

kql_path = utils.determine_policy_path('verify-log-ingestion.kql', sample_folder)
kql_query = Path(kql_path).read_text(encoding='utf-8')

logs_found, result, rows = nb_helper.wait_for_kql(
    workspace_resource_id,
    kql_query,
    api_path='/api/query',
    api_version='2020-08-01',
    progress_label='log entries',
)

if logs_found:
    count = int(rows[0][0]) if rows and rows[0] else len(rows)
    print_ok(f'Log ingestion verified ({count} entries) - workbook should now display data')
elif result is not None and result.success:
    print_warning('Logs did not appear within the polling window')
    print_info('Tips:')
    print_info('  1. Wait a few more minutes and re-run this cell')
    print_info('  2. Verify diagnostic settings in Azure Portal')
    print_info('  3. Re-run the traffic generation cell to send more requests')

# %% [markdown]
# ### 13/14: [Verify] 🔍 Verify Metric Ingestion (Entra ID)
#
# Waits for `caller-requests` custom metrics to arrive in Application Insights, then prints a per-caller breakdown.

# %%
from pathlib import Path

if not enable_entraid_tracking:
    print_info('Entra ID tracking disabled - skipping metric verification')
elif 'app_insights_name' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)
else:
    print_info('Waiting for caller-requests custom metrics to arrive in Application Insights...')
    print()
    print_val('Application Insights', app_insights_name)

    # Build the Application Insights resource ID for the ARM query endpoint
    app_insights_resource_id = (
        f'/subscriptions/{subscription_id}'
        f'/resourceGroups/{rg_name}'
        f'/providers/microsoft.insights/components/{app_insights_name}'
    )

    kql_path = utils.determine_policy_path('verify-metric-ingestion.kql', sample_folder)
    kql_query = Path(kql_path).read_text(encoding='utf-8')

    metrics_found, result, rows = nb_helper.wait_for_kql(
        app_insights_resource_id,
        kql_query,
        api_path='/query',
        api_version='2018-04-20',
        progress_label='metric entries',
    )

    if metrics_found:
        print_ok(f'Metric ingestion verified ({len(rows)} entries) - Entra ID tab in workbook should now display data')

        # Query per-caller breakdown
        breakdown_kql_path = utils.determine_policy_path('verify-metric-breakdown.kql', sample_folder)
        breakdown_kql = Path(breakdown_kql_path).read_text(encoding='utf-8')
        bd_found, bd_result, bd_rows = nb_helper.wait_for_kql(
            app_insights_resource_id,
            breakdown_kql,
            api_path='/query',
            api_version='2018-04-20',
            schedule=[0],
            progress_label='breakdown rows',
        )

        if bd_found:
            caller_lookup = {c['appid']: c['name'] for c in simulated_callers}

            print()
            print_info('Metric Breakdown by Caller:')
            print()
            table_rows = []
            total = 0
            for row in bd_rows:
                caller_id = row[0]
                count = int(row[1])
                name = caller_lookup.get(caller_id, 'Unknown')
                table_rows.append([caller_id, name, count])
                total += count

            table = TableLogger()
            table.header(Column('App ID', width=40), Column('Caller Name', width=20), Column('Requests', width=10, align='>'))
            table.populate(table_rows)
            table.total('TOTAL', '', total)
            table.print()

    elif result is not None and result.success:
        print_warning('Metrics did not appear within the polling window')
        print_info('Tips:')
        print_info('  1. Wait a few more minutes and re-run this cell')
        print_info('  2. Verify the emit-metric policy is applied in Azure Portal')
        print_info('  3. Re-run the Entra ID traffic generation cell to send more requests')

# %% [markdown]
# ### 14/14: [Verify] 🔗 Verify Costing Setup & Ground-Truth Summary
#
# Open these resources in the Azure Portal to verify the sample is working. They are listed in priority order.
#
# 1. **Azure Monitor Workbook** - Confirm the cost dashboard renders and shows per-business-unit request breakdowns.
# 2. **Log Analytics Workspace** - Open the **Logs** blade and run a query against `ApiManagementGatewayLogs` to verify subscription-level data is flowing.
# 3. **Cost Management Exports** - Check that the scheduled export exists and, after its first run, that CSV files appear in the storage container.
# 4. **APIM Service** - Review the subscriptions blade to confirm all business-unit subscriptions are active.
#
# The cell also reads `bu-request-counts.local.json` and prints tables that mirror the headline tiles in the Azure Monitor workbook so you can cross-reference the notebook's intended traffic against what the workbook reports once log ingestion completes.
#
# The tile-style table below shows the same hierarchy used on the workbook's main tab:
#
# | Workbook tile | Notebook source |
# |---|---|
# | **Total APIM Requests** | `sum(plannedRequests / totalRequests)` across **all** traffic sources |
# | **AI APIM Requests** (all subs) | `sum(...)` across sources where `isAi = true` |
# | **AI Requests Received** (bu-*) | `sum(...)` across AI sources that carry a `businessUnits` array (subscription key starts with `bu-`) |
# | **Non-AI Requests** (bu-*) | `sum(...)` across sources where `isAi = false` |
#
# `planned` is the intended request count from the notebook's traffic loops. `delivered` is the count that actually received an HTTP response from APIM (matching what `ApiManagementGatewayLogs` will show after ingestion). The two should be equal under healthy conditions; gaps indicate timeouts or transport errors.

# %%
import json
from pathlib import Path

from console import print_plain

base_url = 'https://portal.azure.com/#@/resource'
rg_path = f'/subscriptions/{subscription_id}/resourceGroups/{rg_name}'

# ---- Priority-ordered links for verifying the costing sample ----
print_info('1. Azure Monitor Workbook (cost dashboard)')
if 'workbook_id' in locals() and workbook_id:
    print_plain(f'       {base_url}{workbook_id}/workbook')
else:
    print_plain('   (not deployed)')
print_plain()

print_info('2. Log Analytics Workspace (run KQL queries)')
print_plain(f'       {base_url}{rg_path}/providers/Microsoft.OperationalInsights/workspaces/{log_analytics_name}/Overview')
print_plain()

print_info('3. Cost Management Exports (verify cost data)')
print_plain('       https://portal.azure.com/#view/Microsoft_Azure_CostManagement/Menu/~/exports')
print_plain()

print_info('4. APIM Service (subscriptions & APIs)')
print_plain(f'       {base_url}{rg_path}/providers/Microsoft.ApiManagement/service/{apim_name}/overview')
print_plain()

if enable_foundry and 'foundry_project_name' in locals() and foundry_project_name:
    print_info('5. Microsoft Foundry Project')
    print_plain('      https://ai.azure.com')
    print_plain()

    print_info('6. Azure AI Services (AOAI model deployment)')
    print_plain(f'       {base_url}{rg_path}/providers/Microsoft.CognitiveServices/accounts/{aoai_name}/overview')
    print_plain()

print_ok('Setup complete!')
print_info('To clean up resources, open and run: clean-up.ipynb')

# ---- Ground-truth request summary (cross-reference against the workbook) ----
print()
print()

local_data_path = Path(utils.determine_policy_path('bu-request-counts.local.json', sample_folder))

if not local_data_path.exists():
    print_warning(f'No ground-truth file found at: {local_data_path}')
    print_info('Run the traffic cells (7/14, 10/14 or 11/14) first to generate the file.')
else:
    data = json.loads(local_data_path.read_text(encoding='utf-8'))
    sources = data.get('trafficSources', [])

    # ---- Tile-style aggregates (mirror workbook headline tiles) ----
    total_planned    = sum(s.get('plannedRequests', 0) for s in sources)
    total_delivered  = sum(s.get('totalRequests',   0) for s in sources)

    ai_sources       = [s for s in sources if s.get('isAi')]
    ai_planned       = sum(s.get('plannedRequests', 0) for s in ai_sources)
    ai_delivered     = sum(s.get('totalRequests',   0) for s in ai_sources)

    ai_bu_sources    = [s for s in ai_sources if 'businessUnits' in s]
    ai_bu_planned    = sum(s.get('plannedRequests', 0) for s in ai_bu_sources)
    ai_bu_delivered  = sum(s.get('totalRequests',   0) for s in ai_bu_sources)

    non_ai_sources   = [s for s in sources if not s.get('isAi')]
    non_ai_planned   = sum(s.get('plannedRequests', 0) for s in non_ai_sources)
    non_ai_delivered = sum(s.get('totalRequests',   0) for s in non_ai_sources)

    print_info('Workbook-tile cross-reference (from bu-request-counts.local.json)')
    print_val('Generated UTC', data.get('generatedUtc', ''))
    print_val('Resource group', data.get('resourceGroup', ''))
    print_val('APIM service',   data.get('apimService', ''))
    print()

    tile_table = TableLogger()
    tile_table.header(
        Column('Tile (workbook equivalent)', width=44),
        Column('Planned',   width=10, align='>'),
        Column('Delivered', width=10, align='>'),
    )
    tile_table.populate([
        ['Total APIM Requests (all subs, all APIs)',     total_planned,    total_delivered],
        ['  - Non-AI Requests (bu-*)',                   non_ai_planned,   non_ai_delivered],
        ['  - AI APIM Requests (all subs)',              ai_planned,       ai_delivered],
        ['     of which: AI Requests Received (bu-*)',   ai_bu_planned,    ai_bu_delivered],
    ])
    tile_table.print()
    print()

    # ---- Per-source breakdown ----
    print_info('Traffic sources')
    src_table = TableLogger()
    src_table.header(
        Column('Source',      width=36),
        Column('API path',    width=28),
        Column('AI',          width=4),
        Column('Attribution', width=14),
        Column('Planned',     width=10, align='>'),
        Column('Delivered',   width=10, align='>'),
    )
    src_rows = []
    for s in sources:
        if 'businessUnits' in s:
            attribution = 'business units'
        elif 'callers' in s:
            attribution = 'callers'
        else:
            attribution = '-'
        src_rows.append([
            s.get('name', ''),
            s.get('apiName', ''),
            'yes' if s.get('isAi') else 'no',
            attribution,
            s.get('plannedRequests', 0),
            s.get('totalRequests', 0),
        ])
    src_table.populate(src_rows)
    src_table.total('TOTAL', '', '', '', total_planned, total_delivered)
    src_table.print()
    print()

    # ---- Per-BU rollup across all BU-attributed sources ----
    bu_rollup: dict[str, dict] = {}
    for s in sources:
        for bu in s.get('businessUnits', []):
            entry = bu_rollup.setdefault(bu['name'], {
                'display'     : bu.get('display_name', ''),
                'planned'     : 0,
                'delivered'   : 0,
                'ai_planned'  : 0,
                'ai_delivered': 0,
            })
            entry['planned']   += bu.get('planned',  0)
            entry['delivered'] += bu.get('requests', 0)
            if s.get('isAi'):
                entry['ai_planned']   += bu.get('planned',  0)
                entry['ai_delivered'] += bu.get('requests', 0)

    if bu_rollup:
        print_info('Requests by business unit (sums across all BU-attributed sources)')
        bu_table = TableLogger()
        bu_table.header(
            Column('Business Unit', width=18),
            Column('Display Name',  width=40),
            Column('Planned',       width=10, align='>'),
            Column('Delivered',     width=10, align='>'),
            Column('AI Planned',    width=12, align='>'),
            Column('AI Delivered',  width=14, align='>'),
        )
        gp = gd = gap = gad = 0
        bu_rows = []
        for bu_name in sorted(bu_rollup):
            r = bu_rollup[bu_name]
            bu_rows.append([bu_name, r['display'], r['planned'], r['delivered'], r['ai_planned'], r['ai_delivered']])
            gp  += r['planned']
            gd  += r['delivered']
            gap += r['ai_planned']
            gad += r['ai_delivered']
        bu_table.populate(bu_rows)
        bu_table.total('TOTAL', '', gp, gd, gap, gad)
        bu_table.print()
        print()

    # ---- Caller breakdown (AI sources that don't carry bu-* attribution) ----
    caller_sources = [s for s in sources if 'callers' in s]
    for s in caller_sources:
        print_info(f'Caller breakdown - {s.get("name", "")} (api: {s.get("apiName", "")})')
        ct = TableLogger()
        ct.header(
            Column('App ID',      width=40),
            Column('Caller Name', width=24),
            Column('Planned',     width=10, align='>'),
            Column('Delivered',   width=10, align='>'),
        )
        cp = cd = 0
        cr = []
        for c in s.get('callers', []):
            cr.append([c.get('appid', ''), c.get('name', ''), c.get('planned', 0), c.get('requests', 0)])
            cp += c.get('planned', 0)
            cd += c.get('requests', 0)
        ct.populate(cr)
        ct.total('TOTAL', '', cp, cd)
        ct.print()
        print()

    print_ok('Cross-reference tables ready - compare against the Azure Monitor workbook tiles once log ingestion completes.')
    print_info(f'File: {local_data_path}')
