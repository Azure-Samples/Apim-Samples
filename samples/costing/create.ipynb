# %% [markdown]
# ### 🛠️ A1 — Initialize
#
# Configure deployment parameters, feature toggles, business units, and simulated callers. **Modify entries under `USER CONFIGURATION`**; the `SYSTEM CONFIGURATION` block below builds APIs/policies via `_helpers.build_costing_apis` and is not meant to be edited.
#
# | Phase                 | Cells          | Purpose                                       |
# |-----------------------|----------------|-----------------------------------------------|
# | **A. Setup**          | A1, A2         | Initialize, deploy                            |
# | **B. Cost setup**     | B1, B2, B3, B4 | Pricing, cost export, budget alerts           |
# | **C. Non-AI traffic** | C1, C2, C3     | BU subscriptions, AppID JWT, Real JWT         |
# | **D. AI traffic**     | D1, D2         | Real Foundry AOAI, mock token tracking        |
# | **E. Verify**         | E1, E2, E3     | Logs, metrics, cross-reference                |

# %%
import os
import sys
from pathlib import Path

import utils
from apimtypes import APIM_SKU, INFRASTRUCTURE, Region
from azure_resources import get_account_info, get_infra_rg_name
from console import Column, TableLogger, print_error, print_info, print_ok, print_val, print_warning

# Make sample-local helpers (samples/costing/_helpers.py) importable from later cells.
_costing_sample_dir = str(Path(utils.determine_policy_path('_helpers.py', 'costing')).parent)
if _costing_sample_dir not in sys.path:
    sys.path.insert(0, _costing_sample_dir)

from _helpers import build_costing_apis  # noqa: E402  (sys.path mutated above)

# ===============================
#    USER CONFIGURATION
# ===============================

# ═════════════════════════════════
# 1️⃣  DEPLOYMENT & INFRASTRUCTURE
# ═════════════════════════════════
rg_location = Region.EAST_US_2              # Azure region for deployment
index       = 1                             # Infrastructure index (for naming uniqueness when deploying multiple instances)
apim_sku    = APIM_SKU.BASICV2              # APIM pricing tier: 'DEVELOPER', 'BASIC', 'STANDARD', 'PREMIUM', 'BASICV2', 'STANDARDV2', 'PREMIUMV2'
deployment  = INFRASTRUCTURE.SIMPLE_APIM # Note: Target infrastructure - see supported_infras for options:
api_prefix  = 'costing-'                    # API path prefix to avoid naming collisions
tags        = ['costing', 'cost-management', 'observability']  # Resource tags for organization

# ═════════════════════════════════
# 2️⃣  FEATURE TOGGLES (what to deploy)
# ═════════════════════════════════

# Tracking approaches: enable/disable each cost-tracking method
enable_entraid_tracking = True              # Deploy Entra ID tracking API (extract appid from JWT, emit caller metrics)
enable_token_tracking   = True              # Deploy AI Gateway token tracking API (per-caller prompt/completion/total token counts)
# Deploy real Microsoft Foundry + Azure OpenAI (real token tracking via AOAI backend).
# ADDS ~5 MIN + requires Cognitive Services permissions
enable_foundry          = True

# AI token tracking detail (only relevant if enable_token_tracking=True)
# Inject stream_options.include_usage=true into streaming requests so APIM
# diagnostic logs capture exact token counts
force_stream_include_usage = True

# ═════════════════════════════════
# 3️⃣  TRAFFIC EXECUTION (what to run)
# ═════════════════════════════════
# Use these toggles to skip entire traffic phases WITHOUT changing any other config.
# Useful when iterating on workbook/KQL queries without re-generating traffic each time.

run_regular_requests = True                 # Run non-AI traffic (Cells C1-C3): ~525 requests (BU subscriptions + Entra ID + optional real JWT)
run_ai_requests      = True                 # Run AI traffic (Cells D1-D2): ~81 requests (real AOAI if enable_foundry=True, else mock)

# ═════════════════════════════════
# 4️⃣  ADVANCED: REAL ENTRA ID TESTING (optional)
# ═════════════════════════════════
# To test with a REAL Entra ID token (instead of a fake JWT), set use_real_jwt=True
# and populate the three fields below, OR set them via .env (COSTING_JWT_TENANT_ID, etc)

use_real_jwt = False                        # When True, cells C2 send real Entra ID tokens via the emit-metric API
real_jwt_tenant_id     = os.getenv('COSTING_JWT_TENANT_ID', '')          # Your Entra ID tenant GUID
real_jwt_client_id     = os.getenv('COSTING_JWT_CLIENT_ID', '')          # App registration client ID
real_jwt_client_secret = os.getenv('COSTING_JWT_CLIENT_SECRET', '')      # App registration client secret (KEEP SECURE)

# ═════════════════════════════════
# 5️⃣  COST TRACKING & GOVERNANCE
# ═════════════════════════════════

# Cost export frequency (for Cost Management data aggregation)
cost_export_frequency = 'Daily'             # Options: 'Daily', 'Weekly', 'Monthly'

# Budget alerts per business unit
create_budget_alerts = True                 # Deploy Action Group + per-BU scheduled-query alerts (Cell B4)
alert_threshold = 1000                      # Request count threshold per BU per hour (triggers alert if exceeded)
alert_email = 'alerts@contoso.com'          # Email for alerts (leave empty to skip email notifications)

# ═════════════════════════════════
# 6️⃣  SAMPLE DATA & VALIDATION
# ═════════════════════════════════

# Sample traffic generation (for demonstration)
generate_sample_load = True                 # Generate sample API calls to populate cost tracking dashboards
sample_requests_per_subscription = 50       # Base request count per BU (multiplied by each BU's weight factor)


# ===============================
#    SYSTEM CONFIGURATION
# ===============================

sample_folder    = 'costing'
rg_name          = get_infra_rg_name(deployment, index)
# Shared local-only ground-truth file used by C1/D1/D2 (write) and E3 (read).
# Suffix `*.local.json` is gitignored.
local_data_path  = Path(utils.determine_policy_path('bu-request-counts.local.json', sample_folder))
supported_infras = [
    INFRASTRUCTURE.AFD_APIM_PE,
    INFRASTRUCTURE.APIM_ACA,
    INFRASTRUCTURE.APPGW_APIM,
    INFRASTRUCTURE.APPGW_APIM_PE,
    INFRASTRUCTURE.SIMPLE_APIM
]
nb_helper        = utils.NotebookHelper(
    sample_folder,
    rg_name,
    rg_location,
    deployment,
    supported_infras,
    True,
    index = index,
    apim_sku = apim_sku
)

# AI model test matrix - drives which models are deployed to Azure AI Services and
# how many requests per simulated caller are generated against each.
# Each entry: model name -> { version, capacity (K TPM), requests_per_caller }
model_test_matrix = {
    'gpt-5-mini':  {'version': '2025-08-07', 'capacity': 10, 'requests_per_caller': 5},
    'gpt-4o-mini': {'version': '2024-07-18', 'capacity': 10, 'requests_per_caller': 3},
}

# Derived: list form used for Bicep deployment and iteration
ai_models = [
    {'name': name, 'version': cfg['version'], 'capacity': cfg['capacity']}
    for name, cfg in model_test_matrix.items()
]
# Primary model (first entry) - used for pricing defaults baked into the workbook
ai_model_name = next(iter(model_test_matrix))

# Build APIs + policy fragments in one call (assembly logic lives in _helpers.py)
apis, pfs, _api_paths = build_costing_apis(
    api_prefix,
    sample_folder,
    tags,
    enable_entraid_tracking=enable_entraid_tracking,
    enable_token_tracking=enable_token_tracking,
    enable_foundry=enable_foundry,
    force_stream_include_usage=force_stream_include_usage,
)

api_path         = _api_paths['api_path']
entraid_api_path = _api_paths['entraid_api_path']
token_api_path   = _api_paths['token_api_path']
aoai_api_path    = _api_paths['aoai_api_path']

# Simulated caller app IDs (for Entra ID tracking)
simulated_callers = [
    {'appid': 'a5846c0e-1111-4000-8000-000000000001', 'name': 'HR Service',         'request_weight': 1.0},
    {'appid': '9e6bfb3f-2222-4000-8000-000000000002', 'name': 'Finance Portal',     'request_weight': 2.5},
    {'appid': 'c3d2e1f0-3333-4000-8000-000000000003', 'name': 'Mobile Gateway',     'request_weight': 0.5},
    {'appid': 'b7a8c9d0-4444-4000-8000-000000000004', 'name': 'Engineering Tools',  'request_weight': 3.0},
    {'appid': 'd4c5e6f7-5555-4000-8000-000000000005', 'name': 'Sales CRM',          'request_weight': 2.0},
    {'appid': 'e8f9a0b1-6666-4000-8000-000000000006', 'name': 'Operations Console', 'request_weight': 1.5}
]

# Define business units
business_units = [
    {'name': 'bu-hr',          'display': 'Business Unit - Human Resources',  'request_weight': 1.0},
    {'name': 'bu-finance',     'display': 'Business Unit - Finance',          'request_weight': 2.5},
    {'name': 'bu-marketing',   'display': 'Business Unit - Marketing',        'request_weight': 0.5},
    {'name': 'bu-engineering', 'display': 'Business Unit - Engineering',      'request_weight': 3.0},
    {'name': 'bu-sales',       'display': 'Business Unit - Sales',            'request_weight': 2.0},
    {'name': 'bu-operations',  'display': 'Business Unit - Operations',       'request_weight': 1.5}
]

# Quiet "imported but unused" warnings - these names are used by later cells.
_ = (Column, TableLogger, print_info, print_val, print_warning)

print_ok('Notebook initialized')

# Get Azure account information
current_user, current_user_id, tenant_id, subscription_id = get_account_info()

if not subscription_id:
    print_error('Could not determine Azure subscription ID. Run: az login')
    raise SystemExit(1)

# %% [markdown]
# ### 🚀 A2 — Deploy
#
# Deploy the sample's Bicep template (APIs, policy fragments, BU subscriptions, workbook, optional Foundry). Outputs (`apim_name`, `apim_gateway_url`, `app_insights_name`, `log_analytics_name`, `storage_account_name`, `subscriptions`, AOAI details) are exposed as variables for later cells.

# %%
from azure_cost import get_apim_sku_pricing, get_model_pricing

# Derive pricing from the deployed APIM SKU for workbook defaults
sku_pricing = get_apim_sku_pricing(apim_sku)

# Derive per-token pricing for the AI model
model_pricing = get_model_pricing(ai_model_name)

# Build the bicep parameters
bicep_parameters = {
    'location'              : {'value': rg_location},
    'costExportFrequency'   : {'value': cost_export_frequency},
    'index'                 : {'value': index},
    'apis'                  : {'value': [api.to_dict() for api in apis]},
    'businessUnits'         : {'value': [{'name': bu['name'], 'displayName': bu['display']} for bu in business_units]},
    'policyFragments'       : {'value': [pf.to_dict() for pf in pfs]},
    'apimSkuDisplayName'    : {'value': apim_sku.value},
    'baseMonthlyCost'       : {'value': str(sku_pricing.base_monthly_cost)},
    'perKRate'              : {'value': str(sku_pricing.per_k_rate)},
    'promptTokenRate'       : {'value': str(model_pricing.prompt_rate_per_k)},
    'completionTokenRate'   : {'value': str(model_pricing.completion_rate_per_k)},
    'enableFoundry'         : {'value': enable_foundry},
    'aiModels'              : {'value': ai_models}
}

# Deploy the sample
output = nb_helper.deploy_sample(bicep_parameters)

if output.success:
    # Extract deployment outputs
    apim_name                      = output.get('apimServiceName', 'APIM Service Name')
    apim_gateway_url               = output.get('apimResourceGatewayURL', 'APIM API Gateway URL')
    app_insights_name              = output.get('applicationInsightsName', 'Application Insights Name')
    app_insights_connection_string = output.get('applicationInsightsConnectionString', '')
    log_analytics_name             = output.get('logAnalyticsWorkspaceName', 'Log Analytics Workspace Name')
    storage_account_name           = output.get('storageAccountName', 'Storage Account Name')
    workbook_name                  = output.get('workbookName', 'Workbook Name')
    workbook_id                    = output.get('workbookId', '')
    cost_export_name               = f'apim-cost-export-{index}-{rg_name}'

    # Extract BU subscription keys (scoped to cost-tracking API)
    subscription_keys_output       = output.getJson('subscriptionKeys', 'Subscription Keys', secure=True)

    # Foundry outputs (empty strings when enableFoundry = False)
    aoai_endpoint                  = output.get('aoaiEndpoint', '')
    aoai_name                      = output.get('aoaiName', '')
    model_deployment_name          = output.get('modelDeploymentName', '')
    model_deployment_names         = output.getJson('modelDeploymentNames', 'Model Deployment Names') or []
    foundry_hub_name               = output.get('foundryHubName', '')
    foundry_project_name           = output.get('foundryProjectName', '')

    if enable_foundry and aoai_endpoint:
        print_ok(f'Foundry deployed: {foundry_hub_name} / {foundry_project_name}')
        print_val('AOAI Endpoint', aoai_endpoint)
        print_val('Model Deployments', ', '.join(model_deployment_names) if model_deployment_names else model_deployment_name)

    # Per-API subscription keys are retrieved on demand via
    # get_apim_subscription_key() (RBAC-controlled ARM listSecrets).

    # Map APIM subscription keys to business units
    subscriptions = {}
    if subscription_keys_output:
        for bu in business_units:
            sub_id = bu['name']
            primary_key = next((item['primaryKey'] for item in subscription_keys_output if item['name'] == sub_id), None)

            subscriptions[sub_id] = {
                'display_name': bu['display'],
                'primary_key': primary_key,
                'request_weight': bu.get('request_weight', 1.0)
            }

    print_ok('Deployment completed successfully')
else:
    print_error('Deployment failed!')
    raise SystemExit(1)

# %% [markdown]
# ### 📊 B1 — [Setup] Pricing & Cost Model
#
# Display the APIM SKU base cost, overage rate, included requests, and per-token AOAI pricing used by the workbook. All values come from `sku_pricing` and `model_pricing` derived in **A2 (deploy)**, so the printed summary stays in lock-step with what was deployed.
#
# > **Requires A2 to have run.** All B and C/D/E cells depend on the deployment outputs and the `sku_pricing` / `model_pricing` / `subscriptions` / `local_data_path` variables it produces.

# %%
from azure_cost import AOAI_PRICING_AS_OF, AOAI_PRICING_URL, APIM_PRICING_AS_OF, APIM_PRICING_URL, get_model_pricing

# APIM SKU summary
print_val('APIM SKU', apim_sku.value)
print_val('Base monthly cost', f'${sku_pricing.base_monthly_cost:.2f}')
print_val('Overage rate per 1K', f'${sku_pricing.per_k_rate}')
print_val('Included requests (K)', f'{sku_pricing.included_requests_k:,.0f}')
print_info(f'APIM pricing as of {APIM_PRICING_AS_OF}: {APIM_PRICING_URL}', True)
print()

# Per-model pricing table
print_info('AI model pricing (per 1K tokens)')
pricing_table = TableLogger()
pricing_table.header(
    Column('Model'),
    Column('Prompt $/1K', align='>'),
    Column('Completion $/1K', align='>'),
)
pricing_table.populate([
    [m, f'${(mp := get_model_pricing(m)).prompt_rate_per_k:.5f}', f'${mp.completion_rate_per_k:.5f}']
    for m in model_test_matrix
])
pricing_table.print()

print_info(f'Azure OpenAI pricing as of {AOAI_PRICING_AS_OF}: {AOAI_PRICING_URL}', True)

# %% [markdown]
# ### 🔧 B2 — [Setup] Configure Cost Management Export
#
# Create a recurring Cost Management export with a system-assigned managed identity and grant it `Storage Blob Data Contributor` on the deployed storage account. Recreates the export if one with the same name already exists. Implementation lives in `_helpers.configure_cost_export`.

# %%
from _helpers import configure_cost_export

cost_export_configured = configure_cost_export(
    subscription_id=subscription_id,
    rg_name=rg_name,
    storage_account_name=storage_account_name,
    cost_export_name=cost_export_name,
    cost_export_frequency=cost_export_frequency,
)

# %% [markdown]
# ### 📤 B3 — [Setup] Trigger Initial Cost Export
#
# Run the first cost export immediately so data appears in the storage container without waiting for the next scheduled recurrence.

# %%
from azure_resources import run

if not cost_export_configured:
    print_warning('Cost export was not configured - skipping manual run')
else:
    api_version = '2025-03-01'
    print_info(f'Triggering first cost export run for "{cost_export_name}"...')

    run_result = run(
        f'az rest --method POST '
        f'--url "/subscriptions/{subscription_id}/providers/Microsoft.CostManagement/exports/{cost_export_name}'
        f'/run?api-version={api_version}"'
    )

    if run_result.success:
        print_ok('Cost export run triggered successfully')
        print_info('Data will appear in the storage container within a few minutes')
    else:
        print_warning('Could not trigger export run - it will run on its next scheduled recurrence')

# %% [markdown]
# ### 🔔 B4 — [Setup] Budget Alerts per Business Unit
#
# Create an Action Group + per-BU scheduled-query alerts in Log Analytics. Each alert runs `budget-alert-threshold.kql` every 5 minutes over a 1-hour window and emails when a BU exceeds `alert_threshold`. Implementation lives in `_helpers.create_bu_budget_alerts`.
#
# > Adjust `alert_threshold` and `alert_email` in cell A1 to match your environment.

# %%
from _helpers import create_bu_budget_alerts

if not create_budget_alerts:
    print_info('Budget alert creation skipped (create_budget_alerts = False)')
else:
    create_bu_budget_alerts(
        subscription_id=subscription_id,
        rg_name=rg_name,
        rg_location=rg_location,
        log_analytics_name=log_analytics_name,
        alert_email=alert_email,
        alert_threshold=alert_threshold,
        bu_names=list(subscriptions.keys()) or [bu['name'] for bu in business_units],
        sample_folder=sample_folder,
        index=index,
    )

# %% [markdown]
# ### 🏢 C1 — [Traffic · BU Subscriptions] Generate Sample API Traffic
#
# Send weighted traffic from each business unit's APIM subscription key (≈525 requests total) so subscription-level data flows into Application Insights and Log Analytics. This cell drives the per-BU breakdown on the workbook's main tab. Persists ground-truth counts to `bu-request-counts.local.json` for E3 cross-reference.

# %%
from _helpers import build_session, persist_traffic_source, purge_traffic_source, send_requests

if 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)

# Always purge any stale `subscription-based-costing` entry from a prior run
# BEFORE deciding whether to regenerate traffic. This keeps the persisted
# JSON honest when run_regular_requests / generate_sample_load are toggled
# off — otherwise the file would still show last run's request counts.
if purge_traffic_source(local_data_path, 'subscription-based-costing'):
    print_info('Removed stale subscription-based-costing entry from bu-request-counts.local.json')

if generate_sample_load and run_regular_requests:
    print_info('Generating sample API traffic...')

    endpoint_url, request_headers, allow_insecure_tls = utils.get_endpoint(deployment, rg_name, apim_gateway_url)

    # Shared HTTP session (reuses TCP+TLS connections across all business units).
    # Auto-retry on transient TLS / connection resets so a single blip mid-loop
    # doesn't abort the whole traffic-generation run.
    session = build_session(request_headers, allow_insecure_tls, with_retries=True)
    url = f'{endpoint_url}/{api_path}/get'

    # Track planned (intended) vs delivered (got HTTP response) per BU.
    bu_request_counts = []

    try:
        for bu_name, sub_info in subscriptions.items():
            bu_request_count = max(1, int(sample_requests_per_subscription * sub_info.get('request_weight', 1.0)))

            print_info(f'Generating {bu_request_count} requests for {bu_name}')
            delivered = send_requests(
                session, 'GET', url, bu_request_count,
                headers={'api-key': sub_info['primary_key']},
            )

            bu_request_counts.append({
                'name'        : bu_name,
                'display_name': sub_info.get('display_name', ''),
                'weight'      : float(sub_info.get('request_weight', 1.0)),
                'planned'     : bu_request_count,
                'requests'    : delivered,
            })
    finally:
        session.close()

    # --- Print the request count table ---
    print()
    print_info('Business Unit Request Summary:')
    print()

    table = TableLogger()
    table.header(
        Column('Business Unit'), Column('Display Name'),
        Column('Weight', align='>'), Column('Planned', align='>'), Column('Delivered', align='>'),
    )
    table.populate([
        [r['name'], r['display_name'], f'{r["weight"]:.1f}', r['planned'], r['requests']]
        for r in bu_request_counts
    ])
    total_planned = sum(r['planned'] for r in bu_request_counts)
    total_requests = sum(r['requests'] for r in bu_request_counts)
    table.total('TOTAL', '', '', total_planned, total_requests)
    table.print()

    # Persist gitignored ground-truth file used by E3 cross-reference and
    # appended to by the AI traffic cells (D1 + D2).
    persist_traffic_source(
        local_data_path,
        sample_folder=sample_folder,
        rg_name=rg_name,
        apim_name=apim_name,
        source_entry={
            'name'             : 'subscription-based-costing',
            'apiName'          : api_path,
            'isAi'             : False,
            'baseRequestsPerBu': sample_requests_per_subscription,
            'plannedRequests'  : total_planned,
            'totalRequests'    : total_requests,
            'businessUnits'    : [{**r, 'isAi': False} for r in bu_request_counts],
        },
    )

    print()
    print_ok(f'Persisted ground-truth request counts to: {local_data_path}')
    print_info('This file is excluded from git via *.local.json. Use it to cross-check workbook results.')
    print_info('AI traffic cells (D1, D2) will append their own trafficSources entries.')

    print()
    print_info('Note: It may take 2-5 minutes for logs to appear in Application Insights and Log Analytics')
elif not run_regular_requests:
    print_info('Regular request generation skipped (run_regular_requests = False)')
else:
    print_info('Sample load generation skipped (generate_sample_load = False)')

# %% [markdown]
# ### 🆔 C2 — [Traffic · AppID JWT] Entra ID Application Traffic (Mock)
#
# Send traffic with crafted (unsigned) JWTs whose `appid` claim simulates different Entra ID applications. The `emit-metric` policy extracts the claim and emits `caller-requests` custom metrics — drives the workbook's caller-attribution tile.
#
# > Production callers would present real Entra ID tokens. Here we use minimal fake JWTs because the `emit-metric` policy only reads the claim; it does not validate the signature.

# %%
from _helpers import build_session, get_traffic_endpoint, make_fake_jwt, send_requests

if 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)

if enable_entraid_tracking and generate_sample_load and run_regular_requests:
    print_info('Generating sample API traffic with simulated caller app IDs...')

    endpoint_url, request_headers, allow_insecure_tls, entraid_subscription_key = get_traffic_endpoint(
        deployment, rg_name, apim_gateway_url, apim_name,
        api_id=f'api-{api_prefix}appid-tracking-api',
    )

    # Shared HTTP session (reuses TCP+TLS connections across all callers)
    session = build_session(
        request_headers,
        allow_insecure_tls,
        extra_headers={'api-key': entraid_subscription_key},
    )
    url = f'{endpoint_url}/{entraid_api_path}/get'

    # Track planned vs delivered per caller (delivered mirrors backend logs).
    caller_request_counts = []

    try:
        for caller in simulated_callers:
            caller_request_count = max(1, int(sample_requests_per_subscription * caller.get('request_weight', 1.0)))
            fake_jwt = make_fake_jwt(caller['appid'])

            print_info(f'Generating {caller_request_count} requests for {caller["name"]} ({caller["appid"][:12]}...)')
            delivered = send_requests(
                session, 'GET', url, caller_request_count,
                headers={'Authorization': f'Bearer {fake_jwt}'},
            )
            caller_request_counts.append({
                'appid'    : caller['appid'],
                'name'     : caller['name'],
                'weight'   : float(caller.get('request_weight', 1.0)),
                'planned'  : caller_request_count,
                'delivered': delivered,
            })
    finally:
        session.close()

    # Display a summary table of simulated callers
    print()
    print_info('Simulated Caller Summary:')
    print()
    rows = [
        [c['appid'], c['name'], f'{c["weight"]:.1f}', c['planned'], c['delivered']]
        for c in caller_request_counts
    ]
    total_planned = sum(c['planned'] for c in caller_request_counts)
    total_delivered = sum(c['delivered'] for c in caller_request_counts)

    table = TableLogger()
    table.header(
        Column('App ID'), Column('Caller Name'), Column('Weight', align='>'),
        Column('Planned', align='>'), Column('Delivered', align='>'),
    )
    table.populate(rows)
    table.total('TOTAL', '', '', total_planned, total_delivered)
    table.print()

    print()
    print_info('Note: Custom metrics typically take 5-10 minutes to appear in Application Insights')
elif not enable_entraid_tracking:
    print_info('Entra ID tracking disabled (enable_entraid_tracking = False)')
elif not run_regular_requests:
    print_info('Regular request generation skipped (run_regular_requests = False)')
else:
    print_info('Sample load generation skipped (generate_sample_load = False)')

# %% [markdown]
# ### 🔑 C3 — [Traffic · Real JWT] Optional End-to-End Validation
#
# When `use_real_jwt = True`, acquire a real Entra ID token via the **client credentials** flow and send a small batch through the `emit-metric` API. Validates that:
#
# 1. An app registration presents a JWT with a real `appid`.
# 2. The `emit-metric` policy extracts that `appid`.
# 3. A `caller-requests` custom metric is emitted with the real caller ID.
#
# > **Prerequisites:** an [App Registration](https://learn.microsoft.com/entra/identity-platform/quickstart-register-app) and a client secret. No API permissions required — the policy only reads the `appid` claim.

# %%
from _helpers import acquire_entraid_token, build_session, get_traffic_endpoint, send_requests

if not run_regular_requests:
    print_info('Regular request generation skipped (run_regular_requests = False)')
elif not use_real_jwt:
    print_info('Real JWT testing is disabled (use_real_jwt = False)')
    print_info('To enable, set use_real_jwt = True and provide client credentials in the root .env file.')
elif not all([real_jwt_tenant_id, real_jwt_client_id, real_jwt_client_secret]):
    print_error('Missing credentials: set COSTING_JWT_TENANT_ID, COSTING_JWT_CLIENT_ID, and COSTING_JWT_CLIENT_SECRET in the root .env file')
elif 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)
else:
    print_info('Acquiring token from Microsoft Identity Platform...')
    token_result = acquire_entraid_token(real_jwt_tenant_id, real_jwt_client_id, real_jwt_client_secret)

    if token_result is None:
        # acquire_entraid_token already printed the error
        pass
    else:
        access_token, claims = token_result
        real_appid = claims.get('appid', claims.get('azp', 'unknown'))

        print()
        print_info('Token Details:')
        print_val('App ID (appid)', real_appid)
        print_val('Tenant ID (tid)', claims.get('tid', 'unknown'))
        print_val('Token type', claims.get('typ', claims.get('token_type', 'unknown')))
        print()

        endpoint_url, request_headers, allow_insecure_tls, entraid_subscription_key = get_traffic_endpoint(
            deployment, rg_name, apim_gateway_url, apim_name,
            api_id=f'api-{api_prefix}appid-tracking-api',
        )

        # Shared HTTP session (reuses TCP+TLS connections)
        session = build_session(
            request_headers,
            allow_insecure_tls,
            extra_headers={
                'api-key'      : entraid_subscription_key,
                'Authorization': f'Bearer {access_token}',
            },
        )
        url = f'{endpoint_url}/{entraid_api_path}/get'

        real_jwt_request_count = 10  # Small number for testing

        try:
            print_info(f'Sending {real_jwt_request_count} requests with real JWT (appid: {real_appid[:12]}...)')
            delivered = send_requests(session, 'GET', url, real_jwt_request_count)
        finally:
            session.close()

        print()
        print_ok(f'Sent {delivered} of {real_jwt_request_count} requests with real Entra ID token')

# %% [markdown]
# ### 🤖 D1 — [Traffic · AI Foundry] Real AOAI Interactions
#
# When `enable_foundry = True` (default), the deployment provisions an Azure AI Services account with a model deployment plus an APIM backend with managed-identity auth. This cell sends **real** Azure OpenAI chat completions through the APIM gateway across all BUs and models so you see end-to-end token tracking. The mock simulation in D2 is **skipped** when this cell runs so AI traffic numbers reflect only real Foundry calls.
#
# Two delivery modes are exercised per BU per model:
# 1. **Non-streaming** — standard JSON response with a `usage` object.
# 2. **Streaming (SSE)** — half the requests send `stream_options.include_usage = true` themselves; the other half omit it so the APIM policy can add it and log proof in `TraceRecords`.
#
# > **Note:** The outbound policy buffers streaming responses to extract usage. In production, prefer the built-in `azure-openai-emit-token-metric` policy for zero-impact streaming.
#
# > **Double-counting warning:** Do NOT enable both the custom `emit-metric` token tracking and the built-in `azure-openai-emit-token-metric` policy simultaneously — they would emit duplicate metrics.

# %%
import importlib
from itertools import cycle

import _helpers

_helpers = importlib.reload(_helpers)

build_session = _helpers.build_session
get_traffic_endpoint = _helpers.get_traffic_endpoint
make_fake_jwt = _helpers.make_fake_jwt
persist_aoai_traffic = _helpers.persist_aoai_traffic
print_aoai_traffic_summary = _helpers.print_aoai_traffic_summary
purge_traffic_source = _helpers.purge_traffic_source
send_aoai_traffic = _helpers.send_aoai_traffic

# Always purge any stale `ai-gateway-aoai` entry from a prior run BEFORE
# deciding whether to regenerate AI traffic. Keeps the persisted JSON honest
# when run_ai_requests / enable_foundry / enable_token_tracking are toggled
# off - otherwise the file would still show last run's request counts.
if purge_traffic_source(local_data_path, 'ai-gateway-aoai'):
    print_info('Removed stale ai-gateway-aoai entry from bu-request-counts.local.json')

if not run_ai_requests:
    print_info('AI request generation skipped (run_ai_requests = False)')
elif not enable_foundry:
    print_info('Foundry is disabled (enable_foundry = False) - skipping real AOAI interactions')
    print_info('Set enable_foundry = True in the init cell to deploy Foundry and use real AOAI responses')
elif not enable_token_tracking:
    print_info('Token tracking disabled - skipping real AOAI interactions')
elif 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)
elif not aoai_endpoint:
    print_error('AOAI endpoint not available - deployment may have failed')
    raise SystemExit(1)
else:
    print_info('Sending real Azure OpenAI requests through APIM gateway...')
    print_val('AOAI Endpoint', aoai_endpoint)
    print_val('Models', ', '.join(model_test_matrix.keys()))
    print()

    # Sanity-check that the AOAI gateway API is properly subscribed before we
    # send traffic. The returned key is not attached to outgoing requests --
    # the per-BU loop below uses `bu-*` subscription keys so every AOAI request
    # is attributed to a business unit and the workbook tiles reconcile cleanly.
    endpoint_url, request_headers, allow_insecure_tls, _ = get_traffic_endpoint(
        deployment, rg_name, apim_gateway_url, apim_name,
        api_id=f'api-{api_prefix}aoai-gateway',
    )

    # No api-key on the session: each request in the multi-BU loop overrides
    # api-key per call to a `bu-*` subscription key for BU-attributed traffic.
    session = build_session(
        request_headers,
        allow_insecure_tls,
        extra_headers={'Content-Type': 'application/json'},
    )

    # Request bodies reused across the (BU, model) loop. Streaming requests
    # intentionally alternate between client-supplied include_usage=true and
    # omitted include_usage so the APIM policy can prove when it injected it.
    chat_body = {
        'messages': [
            {'role': 'system', 'content': 'You are a helpful assistant. Keep responses brief.'},
            {'role': 'user', 'content': 'What is Azure API Management in one sentence?'},
        ],
        'max_completion_tokens': 100,
    }
    stream_messages = [
        {'role': 'system', 'content': 'You are a helpful assistant. Keep responses brief.'},
        {'role': 'user', 'content': 'What are the benefits of using APIM as an AI Gateway? List three.'},
    ]
    stream_body_with_usage = {
        **chat_body,
        'messages': stream_messages,
        'stream': True,
        'stream_options': {'include_usage': True},
    }
    stream_body_without_usage = {
        **chat_body,
        'messages': stream_messages,
        'stream': True,
    }

    # --- Multi-BU traffic generation (sequential per BU per model) ---
    print_info('Generating multi-BU AOAI traffic for cost tracking (per model)...')

    # Per-model and per-(BU, model) request counters drive the summary tables
    # printed below and the JSON persisted for the workbook cross-reference (E3).
    model_request_counts = {m: {'non_streaming': 0, 'streaming': 0} for m in model_test_matrix}
    bu_model_counts: dict[tuple[str, str], dict[str, int]] = {}
    bu_model_planned: dict[tuple[str, str], dict[str, int]] = {}

    try:
        for model_name, cfg in model_test_matrix.items():
            base_requests = cfg['requests_per_caller']
            model_chat_url = f'{endpoint_url}/{aoai_api_path}/deployments/{model_name}/chat/completions'
            print()
            print_info(f'-> Model: {model_name} (base {base_requests} requests per BU, scaled by request_weight)')

            # Round-robin a caller appid for every BU so gateway logs carry a
            # deterministic appid even when callers and BUs differ in count.
            for (bu_name, bu_info), caller in zip(subscriptions.items(), cycle(simulated_callers)):
                caller_headers = {
                    **session.headers,
                    'Authorization': f'Bearer {make_fake_jwt(caller["appid"])}',
                    # BU subscription key so the AI Gateway tab shows token usage by BU.
                    'api-key': bu_info['primary_key'],
                }

                # Scale per-BU traffic by request_weight so heavier BUs produce
                # proportionally more tokens than lighter ones.
                bu_request_count = max(1, int(base_requests * bu_info.get('request_weight', 1.0)))

                ns, s, planned_ns, planned_s, _ = send_aoai_traffic(
                    session, model_chat_url, caller_headers, bu_request_count,
                    chat_body=chat_body,
                    stream_body=stream_body_with_usage,
                    stream_body_without_usage=stream_body_without_usage,
                )

                model_request_counts[model_name]['streaming'] += s
                model_request_counts[model_name]['non_streaming'] += ns
                bu_model_counts[(bu_name, model_name)] = {'non_streaming': ns, 'streaming': s}
                bu_model_planned[(bu_name, model_name)] = {'non_streaming': planned_ns, 'streaming': planned_s}
                print_ok(
                    f'  Sent {bu_request_count} requests for {bu_name} as {caller["name"]}'
                    f' ({caller["appid"][:12]}...) [{ns} non-streaming, {s} streaming]'
                )
    finally:
        session.close()

    # Summary tables (per-model and per-BU x per-model) - mirror the workbook tiles
    _, _, total_aoai_requests = print_aoai_traffic_summary(model_request_counts, bu_model_counts)

    print()
    print_ok(f'Total real AOAI requests: {total_aoai_requests}')
    print_info('Each request emits a caller-requests metric entry')
    print_info('Token counts are captured via the APIM diagnostic setting (ApiManagementGatewayLlmLog)')
    print_info(
        'Streaming requests alternate between client-supplied include_usage and '
        'policy-injected include_usage; the workbook surfaces this via TraceRecords'
    )
    print_info('Note: Custom metrics typically take 5-10 minutes to appear in Application Insights')

    # Persist BU-level rollup for the AI Gateway tab cross-reference (read by E3).
    persist_aoai_traffic(
        local_data_path,
        sample_folder=sample_folder,
        rg_name=rg_name,
        apim_name=apim_name,
        aoai_api_path=aoai_api_path,
        subscriptions=subscriptions,
        bu_model_counts=bu_model_counts,
        bu_model_planned=bu_model_planned,
    )
    print()
    print_ok(f'Persisted AI Gateway request counts to: {local_data_path}')

# %% [markdown]
# ### 🤖 D2 — [Traffic · AI Mock] Mock Token Tracking (Skipped When Foundry Is On)
#
# When `enable_foundry = False`, this cell exercises the AI-gateway pattern against a mock backend (`httpbin`) so you can see per-caller `caller-tokens` custom metrics without provisioning Foundry. When D1 sent real Foundry traffic, this cell is **skipped** to avoid muddling the AI request counts shown in the workbook.
#
# The mock policy returns a hard-coded usage payload like:
#
# ```json
# { "usage": { "prompt_tokens": 100, "completion_tokens": 200, "total_tokens": 300 } }
# ```
#
# The `emit-metric` policy reads those fields and emits separate `prompt-tokens`, `completion-tokens`, and `total-tokens` metric entries — same shape as the real Foundry traffic from D1.

# %%
from _helpers import (
    build_session,
    get_traffic_endpoint,
    make_fake_jwt,
    persist_traffic_source,
    purge_traffic_source,
    send_requests,
)

# Always purge any stale `ai-gateway-token-tracking` entry from a prior run
# BEFORE deciding whether to regenerate token-tracking traffic. Keeps the
# persisted JSON honest when run_ai_requests / enable_token_tracking are
# toggled off, or when enable_foundry causes this cell to short-circuit.
if purge_traffic_source(local_data_path, 'ai-gateway-token-tracking'):
    print_info('Removed stale ai-gateway-token-tracking entry from bu-request-counts.local.json')

if not run_ai_requests:
    print_info('AI request generation skipped (run_ai_requests = False)')
elif not enable_token_tracking:
    print_info('Token tracking disabled (enable_token_tracking = False)')
elif enable_foundry:
    # Real Foundry traffic in cell D1 already covers caller-attribution. Running
    # this mock loop in addition would inflate AI traffic counts in the workbook.
    print_info('enable_foundry = True - skipping mock token-tracking traffic')
    print_info('Cell D1 sends real AOAI traffic with caller attribution; this mock cell could be confusing then.')
    print_info('Set enable_foundry = False to use the mock httpbin AOAI backend instead.')
elif 'apim_gateway_url' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)
else:
    print_info('Generating AI Gateway traffic with simulated callers...')
    print_info('The emit-metric policy will emit caller-requests metrics per caller identity')
    print_info('Each response carries a hard-coded usage payload (~10-700 tokens/req)')
    print()

    endpoint_url, request_headers, allow_insecure_tls, token_subscription_key = get_traffic_endpoint(
        deployment, rg_name, apim_gateway_url, apim_name,
        api_id=f'api-{api_prefix}token-tracking-api',
    )

    token_requests_per_caller = 20  # Fewer requests needed since each emits 3 metric entries

    # Shared HTTP session (reuses TCP+TLS connections across all callers)
    session = build_session(
        request_headers,
        allow_insecure_tls,
        extra_headers={'api-key': token_subscription_key},
    )
    url = f'{endpoint_url}/{token_api_path}/get'

    # Track delivered (got an HTTP response from APIM) and planned counts per
    # caller so the persisted JSON mirrors what backend logs will show.
    caller_delivered: dict[str, int] = {}
    caller_planned: dict[str, int] = {}

    try:
        for caller in simulated_callers:
            caller_request_count = max(1, int(token_requests_per_caller * caller.get('request_weight', 1.0)))
            fake_jwt = make_fake_jwt(caller['appid'])
            caller_planned[caller['appid']] = caller_request_count

            print_info(f'Generating {caller_request_count} requests for {caller["name"]} ({caller["appid"][:12]}...)')
            caller_delivered[caller['appid']] = send_requests(
                session, 'GET', url, caller_request_count,
                headers={'Authorization': f'Bearer {fake_jwt}'},
            )
    finally:
        session.close()

    # Display summary table
    print()
    print_info('AI Gateway Token Traffic Summary:')
    print()
    rows = [
        [c['appid'], c['name'], f'{c["request_weight"]:.1f}',
         caller_planned.get(c['appid'], 0), caller_delivered.get(c['appid'], 0)]
        for c in simulated_callers
    ]
    total_planned = sum(caller_planned.values())
    total_reqs = sum(caller_delivered.values())

    table = TableLogger()
    table.header(
        Column('App ID'), Column('Caller Name'), Column('Weight', align='>'),
        Column('Planned', align='>'), Column('Delivered', align='>'),
    )
    table.populate(rows)
    table.total('TOTAL', '', '', total_planned, total_reqs)
    table.print()
    print()
    print_info(f'Expected caller-requests metric entries: ~{total_reqs}')
    print_info('Note: Custom metrics typically take 5-10 minutes to appear in Application Insights')

    print_info('Verification of caller-requests ingestion runs once in cell E2 (Verify Metric Ingestion)')
    print_info('Token-level data is available in ApiManagementGatewayLlmLog via the APIM diagnostic setting')
    print_info('See bu-token-usage.kql for a query that joins request logs with token counts')

    # --- Persist token-tracking request counts to the shared local JSON file ---
    # Token-tracking traffic is caller-attributed (no bu-* subscription key) so it
    # records a `callers` array instead of `businessUnits`. It does NOT appear in
    # the AI Gateway workbook tab's BU breakdown but DOES count toward 'AI APIM
    # Requests' and 'Total APIM Requests' tiles.
    callers_persisted = [
        {
            'appid'   : c['appid'],
            'name'    : c['name'],
            'weight'  : float(c.get('request_weight', 1.0)),
            'planned' : caller_planned.get(c['appid'], 0),
            'requests': caller_delivered.get(c['appid'], 0),
            'isAi'    : True,
        }
        for c in simulated_callers
    ]

    persist_traffic_source(
        local_data_path,
        sample_folder=sample_folder,
        rg_name=rg_name,
        apim_name=apim_name,
        source_entry={
            'name'           : 'ai-gateway-token-tracking',
            'apiName'        : token_api_path,
            'isAi'           : True,
            'plannedRequests': total_planned,
            'totalRequests'  : total_reqs,
            'callers'        : callers_persisted,
        },
    )

    print()
    print_ok(f'Persisted token-tracking request counts to: {local_data_path}')

# %% [markdown]
# ### 🔍 E1 — [Verify] Log Ingestion
#
# Poll Log Analytics for `ApiManagementGatewayLogs` and `ApiManagementGatewayLlmLog` until the rows from the C/D traffic cells appear. Log Analytics ingestion typically lags real time by 2-5 minutes; this cell retries on a backoff so the rest of the verification can run unattended.

# %%
from pathlib import Path

if 'log_analytics_name' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)

print_info('Waiting for APIM logs to arrive in Log Analytics...')
print()
print_val('Workspace', log_analytics_name)

# Build the workspace resource ID for the ARM query endpoint
workspace_resource_id = (
    f'/subscriptions/{subscription_id}'
    f'/resourceGroups/{rg_name}'
    f'/providers/Microsoft.OperationalInsights/workspaces/{log_analytics_name}'
)

kql_path = utils.determine_policy_path('verify-log-ingestion.kql', sample_folder)
kql_query = Path(kql_path).read_text(encoding='utf-8')

logs_found, result, rows = nb_helper.wait_for_kql(
    workspace_resource_id,
    kql_query,
    api_path='/api/query',
    api_version='2020-08-01',
    progress_label='log entries',
)

if logs_found:
    print_ok(f'Log ingestion verified ({int(rows[0][0])} entries) - workbook should now display data')
elif result is not None and result.success:
    print_warning('Logs did not appear within the polling window')
    print_info('Tips:')
    print_info('  1. Wait a few more minutes and re-run this cell')
    print_info('  2. Verify diagnostic settings in Azure Portal')
    print_info('  3. Re-run the traffic generation cell to send more requests')

# %% [markdown]
# ### 🔍 E2 — [Verify] Metric Ingestion
#
# Poll Application Insights for the `caller-requests`, `prompt-tokens`, `completion-tokens`, and `total-tokens` custom metrics emitted by the `emit-metric` policies in C2/D1/D2. Custom metric ingestion can take 5-10 minutes after first emission.

# %%
from pathlib import Path

if not enable_entraid_tracking:
    print_info('Entra ID tracking disabled - skipping metric verification')
elif 'app_insights_name' not in locals():
    print_error('Please run the deployment cell first')
    raise SystemExit(1)
else:
    print_info('Waiting for caller-requests custom metrics to arrive in Application Insights...')
    print()
    print_val('Application Insights', app_insights_name)

    # Build the Application Insights resource ID for the ARM query endpoint
    app_insights_resource_id = (
        f'/subscriptions/{subscription_id}'
        f'/resourceGroups/{rg_name}'
        f'/providers/microsoft.insights/components/{app_insights_name}'
    )

    kql_path = utils.determine_policy_path('verify-metric-ingestion.kql', sample_folder)
    kql_query = Path(kql_path).read_text(encoding='utf-8')

    metrics_found, result, rows = nb_helper.wait_for_kql(
        app_insights_resource_id,
        kql_query,
        api_path='/query',
        api_version='2018-04-20',
        progress_label='metric entries',
    )

    if metrics_found:
        print_ok(f'Metric ingestion verified ({len(rows)} entries) - Entra ID tab in workbook should now display data')

        # Query per-caller breakdown
        breakdown_kql_path = utils.determine_policy_path('verify-metric-breakdown.kql', sample_folder)
        breakdown_kql = Path(breakdown_kql_path).read_text(encoding='utf-8')
        bd_found, bd_result, bd_rows = nb_helper.wait_for_kql(
            app_insights_resource_id,
            breakdown_kql,
            api_path='/query',
            api_version='2018-04-20',
            schedule=[0],
            progress_label='breakdown rows',
        )

        if bd_found:
            caller_lookup = {c['appid']: c['name'] for c in simulated_callers}

            print()
            print_info('Metric Breakdown by Caller:')
            print()
            table_rows = []
            total = 0
            for row in bd_rows:
                caller_id = row[0]
                count = int(row[1])
                name = caller_lookup.get(caller_id, 'Unknown')
                table_rows.append([caller_id, name, count])
                total += count

            table = TableLogger()
            table.header(Column('App ID'), Column('Caller Name'), Column('Requests', align='>'))
            table.populate(table_rows)
            table.total('TOTAL', '', total)
            table.print()

    elif result is not None and result.success:
        print_warning('Metrics did not appear within the polling window')
        print_info('Tips:')
        print_info('  1. Wait a few more minutes and re-run this cell')
        print_info('  2. Verify the emit-metric policy is applied in Azure Portal')
        print_info('  3. Re-run the Entra ID traffic generation cell to send more requests')

# %% [markdown]
# ### 🔗 E3 — [Verify] Cross-Reference & Ground Truth
#
# Print priority-ordered Azure portal links (Workbook, Log Analytics, Cost Exports, APIM, optional Foundry) plus the ground-truth tables that mirror the workbook's headline tiles.
#
# The tables read from `bu-request-counts.local.json` (written by C1/D1/D2) so you can compare the notebook's intended/delivered counts against what the Azure Monitor workbook reports once log ingestion completes.
#
# | Workbook tile | Notebook source |
# |---|---|
# | **Total APIM Requests** | `sum(plannedRequests / totalRequests)` across **all** traffic sources |
# | **AI APIM Requests** (all subs) | `sum(...)` across sources where `isAi = true` |
# | **AI Requests Received** (bu-*) | `sum(...)` across AI sources that carry a `businessUnits` array |
# | **Non-AI Requests** (bu-*) | `sum(...)` across sources where `isAi = false` |
#
# `planned` is the intended request count from the C/D traffic loops; `delivered` is the count that actually received an HTTP response (matches `ApiManagementGatewayLogs` after ingestion). Gaps indicate timeouts or transport errors.

# %%
from _helpers import print_portal_links, print_workbook_cross_reference

# ---- Ground-truth request summary (cross-reference against the workbook) ----
print()
print()
print_workbook_cross_reference(local_data_path)

# ---- Priority-ordered links (workbook first, then reference links) ----
base_url = 'https://portal.azure.com/#@/resource'
rg_path = f'/subscriptions/{subscription_id}/resourceGroups/{rg_name}'

workbook_url = f'{base_url}{workbook_id}/workbook' if locals().get('workbook_id') else None

links: list[tuple[str, str | None]] = [
    ('Azure Monitor Workbook (cost dashboard)', workbook_url),
    ('Log Analytics Workspace (run KQL queries)',
     f'{base_url}{rg_path}/providers/Microsoft.OperationalInsights/workspaces/{log_analytics_name}/Overview'),
    ('Cost Management Exports (verify cost data)',
     'https://portal.azure.com/#view/Microsoft_Azure_CostManagement/Menu/~/exports'),
    ('APIM Service (subscriptions & APIs)',
     f'{base_url}{rg_path}/providers/Microsoft.ApiManagement/service/{apim_name}/overview'),
]

if enable_foundry and locals().get('foundry_project_name'):
    links.append(('Microsoft Foundry Project', 'https://ai.azure.com'))
    links.append((
        'Azure AI Services (AOAI model deployment)',
        f'{base_url}{rg_path}/providers/Microsoft.CognitiveServices/accounts/{aoai_name}/overview',
    ))

# The portal links can be a bit overwhelming. Let's keep them commented out but available for testing.
print_portal_links(links)

print_ok('Setup complete!', blank_above=True)
print_info('To clean up resources, open and run: clean-up.ipynb')
