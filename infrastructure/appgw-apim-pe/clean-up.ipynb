# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
import utils
from apimtypes import INFRASTRUCTURE

deployment  = INFRASTRUCTURE.APPGW_APIM_PE
indexes     = [30]

utils.cleanup_infra_deployments(deployment, indexes)
# Out:
# 👉🏽 Cleaning up resources for appgw-apim-pe - 30
# 👉🏽 Resource group : apim-infra-appgw-apim-pe-30
# 👉🏽 Deleting and purging API Management 'apim-sxj2v2cucte2c'...
# 👉🏽 Deleting and purging Key Vault 'kv-sxj2v2cucte2c'...
# ℹ️ Deleting resource group 'apim-infra-appgw-apim-pe-30'... ⌚ 12:09:01.595734
# ℹ️ Cleanup completed. ⌚ 12:27:12.782849
#
# ✅ Cleanup completed! ⌚ 12:27:12.784817
