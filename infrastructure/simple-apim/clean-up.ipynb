# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
from apimtypes import INFRASTRUCTURE
from infrastructures import cleanup_infra_deployments

indexes = [10]

cleanup_infra_deployments(INFRASTRUCTURE.SIMPLE_APIM, indexes)
# Out:
# ℹ️ Cleaning up resources for simple-apim - 10
# ℹ️ Resource group : apim-infra-simple-apim-10
#
# ⚙️ az deployment group show --name simple-apim -g apim-infra-simple-apim-10 -o json --debug
#
# Azure CLI: added --debug based on APIM_SAMPLES_LOG_LEVEL=DEBUG
# ℹ️ Cleaning up resources for simple-apim - 10
# ℹ️ Resource group : apim-infra-simple-apim-10
#
# ⚙️ az deployment group show --name simple-apim -g apim-infra-simple-apim-10 -o json --debug
#
# Azure CLI: added --debug based on APIM_SAMPLES_LOG_LEVEL=DEBUG
# DEBUG: cli.knack.cli: Command arguments: ['deployment', 'group', 'show', '--name', 'simple-apim', '-g', 'apim-infra-simple-apim-10', '-o', 'json', '--debug']
# DEBUG: cli.knack.cli: __init__ debug log:
# Cannot enable color.
# DEBUG: cli.knack.cli: Event: Cli.PreExecute []
# DEBUG: cli.knack.cli: Event: CommandParser.OnGlobalArgumentsCreate [<function CLILogging.on_global_arguments at 0x000001E79F3B44A0>, <function OutputProducer.on_global_arguments at 0x000001E79F94D800>, <function
# CLIQuery.on_global_arguments at 0x000001E79F99F740>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreCommandTableCreate []
# DEBUG: cli.azure.cli.core: Modules found from index for 'deployment': ['azure.cli.command_modules.resource']
# DEBUG: cli.azure.cli.core: Loading command modules:
# DEBUG: cli.azure.cli.core: Name                  Load Time    Groups  Commands
# DEBUG: cli.azure.cli.core: resource                  1.199        52       234
# DEBUG: cli.azure.cli.core: Total (1)                 1.199        52       234
# DEBUG: cli.azure.cli.core: These extensions are not installed and will be skipped: ['azext_ai_examples', 'azext_next']
# DEBUG: cli.azure.cli.core: Loading extensions:
# DEBUG: cli.azure.cli.core: Name                  Load Time    Groups  Commands  Directory
# DEBUG: cli.azure.cli.core: Total (0)                 0.000         0         0
# DEBUG: cli.azure.cli.core: Loaded 52 groups, 234 commands.
# DEBUG: cli.azure.cli.core: Found a match in the command table.
# DEBUG: cli.azure.cli.core: Raw command  : deployment group show
# DEBUG: cli.azure.cli.core: Command table: deployment group show
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreCommandTableTruncate [<function AzCliLogging.init_command_file_logging at 0x000001E7A2131080>]
# DEBUG: cli.azure.cli.core.azlogging: metadata file logging enabled - writing logs to 'C:\Users\simonkurtz\.azure\commands\2025-12-15.23-00-37.deployment_group_show.20688.log'.
# INFO: az_command_data_logger: command args: deployment group show --name {} -g {} -o {} --debug
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreArgumentLoad [<function register_global_subscription_argument.<locals>.add_subscription_parameter at 0x000001E7A216A5C0>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPostArgumentLoad []
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPostCommandTableCreate [<function register_ids_argument.<locals>.add_ids_arguments at 0x000001E7A21AC900>, <function register_cache_arguments.<locals>.add_cache_arguments at
# 0x000001E7A21ACAE0>, <function register_upcoming_breaking_change_info.<locals>.update_breaking_change_info at 0x000001E7A21ACB80>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnCommandTableLoaded []
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreParseArgs []
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPostParseArgs [<function OutputProducer.handle_output_argument at 0x000001E79F94D8A0>, <function CLIQuery.handle_query_parameter at 0x000001E79F99F7E0>, <function
# register_ids_argument.<locals>.parse_ids_arguments at 0x000001E7A21AC9A0>]
# DEBUG: cli.azure.cli.core.commands.client_factory: Getting management service client client_type=DeploymentsMgmtClient
# DEBUG: cli.azure.cli.core.auth.persistence: build_persistence: location='C:\\Users\\simonkurtz\\.azure\\msal_token_cache.bin', encrypt=True
# DEBUG: cli.azure.cli.core.auth.binary_cache: load: C:\Users\simonkurtz\.azure\msal_http_cache.bin
# DEBUG: urllib3.util.retry: Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# DEBUG: msal.authority: Initializing with Entra authority: https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3
# DEBUG: msal.authority: openid_config("https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/v2.0/.well-known/openid-configuration") = {'token_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/token', 'token_endpoint_auth_methods_supported': ['client_secret_post', 'private_key_jwt', 'client_secret_basic',
# 'self_signed_tls_client_auth'], 'jwks_uri': 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/discovery/v2.0/keys', 'response_modes_supported': ['query', 'fragment', 'form_post'],
# 'subject_types_supported': ['pairwise'], 'id_token_signing_alg_values_supported': ['RS256'], 'response_types_supported': ['code', 'id_token', 'code id_token', 'id_token token'], 'scopes_supported': ['openid', 'profile',
# 'email', 'offline_access'], 'issuer': 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/v2.0', 'request_uri_parameter_supported': False, 'userinfo_endpoint':
# 'https://graph.microsoft.com/oidc/userinfo', 'authorization_endpoint': 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/authorize', 'device_authorization_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/devicecode', 'http_logout_supported': True, 'frontchannel_logout_supported': True, 'end_session_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/logout', 'claims_supported': ['sub', 'iss', 'cloud_instance_name', 'cloud_instance_host_name', 'cloud_graph_host_name', 'msgraph_host',
# 'aud', 'exp', 'iat', 'auth_time', 'acr', 'nonce', 'preferred_username', 'name', 'tid', 'ver', 'at_hash', 'c_hash', 'email'], 'kerberos_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/kerberos', 'mtls_endpoint_aliases': {'token_endpoint': 'https://mtlsauth.microsoft.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/token'},
# 'tls_client_certificate_bound_access_tokens': True, 'tenant_region_scope': 'NA', 'cloud_instance_name': 'microsoftonline.com', 'cloud_graph_host_name': 'graph.windows.net', 'msgraph_host': 'graph.microsoft.com',
# 'rbac_url': 'https://pas.windows.net'}
# DEBUG: msal.application: Broker enabled? True
# DEBUG: cli.azure.cli.core.auth.credential_adaptor: CredentialAdaptor.get_token_info: scopes=('https://management.core.windows.net//.default',), options={}
# DEBUG: cli.azure.cli.core.auth.msal_credentials: UserCredential.acquire_token: scopes=['https://management.core.windows.net//.default'], claims_challenge=None, kwargs={}
# DEBUG: msal.application: Cache hit an AT
# DEBUG: msal.telemetry: Generate or reuse correlation_id: 46587464-a82c-49fd-9f94-209ef8854c27
# DEBUG: cli.azure.cli.core.sdk.policies: Request URL:
# 'https://management.azure.com/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourcegroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/simple-apim?api-version=2025-04-01'
# DEBUG: cli.azure.cli.core.sdk.policies: Request method: 'GET'
# DEBUG: cli.azure.cli.core.sdk.policies: Request headers:
# DEBUG: cli.azure.cli.core.sdk.policies:     'Accept': 'application/json'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-client-request-id': 'c6c00777-da33-11f0-be91-b85c5c0a1952'
# DEBUG: cli.azure.cli.core.sdk.policies:     'CommandName': 'deployment group show'
# DEBUG: cli.azure.cli.core.sdk.policies:     'ParameterSetName': '--name -g -o --debug'
# DEBUG: cli.azure.cli.core.sdk.policies:     'User-Agent': 'AZURECLI/2.81.0 (MSI) azsdk-python-core/1.35.0 Python/3.13.9 (Windows-11-10.0.26100-SP0)'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Authorization': '*****'
# DEBUG: cli.azure.cli.core.sdk.policies: Request body:
# DEBUG: cli.azure.cli.core.sdk.policies: This request has no body
# DEBUG: urllib3.connectionpool: Starting new HTTPS connection (1): management.azure.com:443
# DEBUG: urllib3.connectionpool: https://management.azure.com:443 "GET
# /subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourcegroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/simple-apim?api-version=2025-04-01 HTTP/1.1" 200 19699
# DEBUG: cli.azure.cli.core.sdk.policies: Response status: 200
# DEBUG: cli.azure.cli.core.sdk.policies: Response headers:
# DEBUG: cli.azure.cli.core.sdk.policies:     'Cache-Control': 'no-cache'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Pragma': 'no-cache'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Content-Length': '19699'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Content-Type': 'application/json; charset=utf-8'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Expires': '-1'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-ratelimit-remaining-subscription-reads': '249'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-ratelimit-remaining-subscription-global-reads': '3749'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-request-id': 'c434d264-3486-46de-8152-c2fe0da5fa95'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-correlation-request-id': 'c434d264-3486-46de-8152-c2fe0da5fa95'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-routing-request-id': 'SOUTHCENTRALUS:20251216T040038Z:c434d264-3486-46de-8152-c2fe0da5fa95'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
# DEBUG: cli.azure.cli.core.sdk.policies:     'X-Content-Type-Options': 'nosniff'
# DEBUG: cli.azure.cli.core.sdk.policies:     'X-Cache': 'CONFIG_NOCACHE'
# DEBUG: cli.azure.cli.core.sdk.policies:     'X-MSEdge-Ref': 'Ref A: 8A7E01908A5B40789B5D51C2AD9A9616 Ref B: SN4AA2022303045 Ref C: 2025-12-16T04:00:38Z'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Date': 'Tue, 16 Dec 2025 04:00:37 GMT'
# DEBUG: cli.azure.cli.core.sdk.policies: Response content:
# DEBUG: cli.azure.cli.core.sdk.policies:
# {"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/simple-apim","name":"simple-apim","type":"Microsoft.Resources/deployments","properties":{"templateHash":"4897489125585507109","parameters":{"location":{"type":"String","value":"eastus2"},"resourceSuffix":{"type":"String","value":"hirrplxxsciuy"},"apimName":{"type":"String","value":"apim-hirrplxxsciuy"},"apimSku":{"type":"String","value":"Basicv2"},"apis":{"type":"Array","value":[{"name":"hello-world","displayName":"Hello
# World","path":"","description":"This is the root API for Hello World","operations":[{"name":"GET","displayName":"GET","urlTemplate":"/","description":"Gets a Hello World message","method":"GET","policyXml":"<!--\n
# This is the default policy that does nothing more than to greet you. There are no backend API calls here.\n-->\n<policies>\n    <inbound>\n        <base />\n        <return-response>\n            <set-status code=\"200\"
# reason=\"OK\" />\n            <set-body>Hello World from API Management!</set-body>\n        </return-response>\n    </inbound>\n    <backend>\n        <base />\n    </backend>\n    <outbound>\n        <base />\n
# </outbound>\n</policies>\n","templateParameters":[]}],"serviceUrl":null,"subscriptionRequired":true,"policyXml":"<!--\n    This is the default policy.\n-->\n<policies>\n    <inbound>\n        <base />\n    </inbound>\n
# <backend>\n        <base />\n    </backend>\n    <outbound>\n        <base />\n
# </outbound>\n</policies>\n","tags":[],"productNames":[]}]},"policyFragments":{"type":"Array","value":[{"name":"Api-Id","policyXml":"<!--\n    Policy Fragment: Extract API ID from API Name\n    \n    Tags are very useful
# to explicitly identify an API as API names or paths may be ambiguous and repetitive. Having explicit IDs can significantly aid with telemetry. \n    As there is no way yet to extract a tag associated with an API in Azure
# API Management using policies, putting such information in the API name is a workable alternative. \n    If the format is consistent, it can be parsed and used in the policies.\n\n    The format we are looking for is
# `<api-name> (api-246)`, where the value in parentheses starts with \"api-\" followed by numeric characters.\n    \n    This fragment extracts the API ID from context.Api.Name and stores it in the \"apiId\" variable.\n
# If the format doesn't match the expected pattern, the variable will be set to an empty string.\n\n    Expected format examples:\n    - \"User Management API (api-246)\" \u2192 extracts \"api-246\"\n    - \"Order Service
# (api-123)\" \u2192 extracts \"api-123\"\n    - \"Payment Gateway (payment-456)\" \u2192 ignored (doesn't start with \"api-\")\n    - \"Simple API\" \u2192 ignored (no parentheses)\n\n
# https://learn.microsoft.com/azure/api-management/api-management-policy-expressions#ref-context-api\n-->\n<fragment>\n\t<set-variable name=\"apiId\" value=\"@{\n        // Use regex to match the pattern: (api-\\d+) at the
# end of the string\n        var match = System.Text.RegularExpressions.Regex.Match(context.Api.Name, @\"\\(api-\\d+\\)$\");\n        \n        // Extract the content within parentheses, removing the parentheses\n
# return (match.Success) ? match.Value.Substring(1, match.Value.Length - 2) : string.Empty;\n    }\" />\n\n\t<choose>\n\t\t<when condition=\"@(!string.IsNullOrEmpty(context.Variables.GetValueOrDefault<string>(\"apiId\",
# string.Empty)))\">\n\t\t\t<trace source=\"API Id Policy Fragment\">\n                <message>@{\n                    return \"Extracted API ID: \" + (string)context.Variables[\"apiId\"];\n
# }</message>\n\t\t\t\t<metadata name=\"ApiId\" value=\"@((string)context.Variables[\"apiId\"])\" />\n\t\t\t</trace>\n\t\t\t<!-- Set a header for downstream services to use -->\n\t\t\t<set-header name=\"X-Api-Id\"
# exists-action=\"override\">\n\t\t\t\t<value>@((string)context.Variables[\"apiId\"])</value>\n\t\t\t</set-header>\n\t\t</when>\n\t</choose>\n</fragment>","description":"Extracts a specific API identifier for
# tracing."},{"name":"AuthZ-Match-All","policyXml":"<!--\n    - Expected context variables:\n      - \"jwt\": The parsed JWT token which should already be set by the pf-authx fragment.\n      - \"authz_roles\": A csv of
# required role GUIDs to check against. All roles must be present.\n      \n    - This fragment blocks access (returns 403) when not ALL required roles are present. If all roles are present, processing continues
# normally.\n-->\n<fragment>\n    <choose>\n        <!-- Check if ALL required role GUIDs are present in the JWT -->\n        <when condition=\"@{\n            var jwt = (Jwt)context.Variables[\"jwt\"];\n            var
# requiredRoleGuids = context.Variables.GetValueOrDefault<string>(\"authz_roles\", \"\").ToString().Split(',');\n            var jwtRoles = jwt.Claims.GetValueOrDefault(\"roles\", new string[0]);\n            \n
# // Check if ALL required role GUIDs are present in the JWT\n            return !requiredRoleGuids.All(requiredRole => jwtRoles.Contains(requiredRole.Trim()));\n        }\">\n            <return-response>\n
# <set-status code=\"403\" reason=\"Forbidden\" />\n                <set-body>Access denied - not all required roles found</set-body>\n            </return-response>\n        </when>\n        <!-- If all roles are present,
# continue processing (no action needed) -->\n    </choose>\n</fragment>\n","description":"Authorizes if all of the specified roles match the JWT role claims."},{"name":"AuthZ-Match-Any","policyXml":"<!--\n    - Expected
# context variables:\n      - \"jwt\": The parsed JWT token which should already be set by the pf-authx fragment.\n      - \"authz_roles\": A csv of allowed role GUIDs to check against. Any match will grant access.\n
# \n    - This fragment only blocks access (returns 403) when no roles match. If roles match, processing continues normally.\n-->\n<fragment>\n    <choose>\n        <!-- Check if NONE of the allowed role GUIDs match the
# roles in the JWT -->\n        <when condition=\"@{\n            var jwt = (Jwt)context.Variables[\"jwt\"];\n            var allowedRoleGuids = context.Variables.GetValueOrDefault<string>(\"authz_roles\",
# \"\").ToString().Split(',');\n            var jwtRoles = jwt.Claims.GetValueOrDefault(\"roles\", new string[0]);\n            \n            // Check if NO allowed role GUID matches any role in the JWT\n            return
# !allowedRoleGuids.Any(allowedRole => jwtRoles.Contains(allowedRole.Trim()));\n        }\">\n            <return-response>\n                <set-status code=\"403\" reason=\"Forbidden\" />\n
# <set-body>Access denied - no matching roles found</set-body>\n            </return-response>\n        </when>\n        <!-- If roles match, continue processing (no action needed) -->\n
# </choose>\n</fragment>","description":"Authorizes if any of the specified roles match the JWT role claims."},{"name":"Http-Response-200","policyXml":"<fragment>\n    <return-response>\n        <set-status code=\"200\"
# reason=\"OK\" />\n        <set-body>\n            @{\n                return \"Successful \" + context.Request.Method;\n            }\n        </set-body>\n    </return-response>\n</fragment>","description":"Returns a
# 200 OK response for the current HTTP method."},{"name":"Product-Match-Any","policyXml":"<!--\n    - Expected context variables:\n      - \"products\": A csv of product names to check against. Any match will allow the
# policy to continue processing.\n      \n    - This fragment only blocks access (returns 403) when no products match. If any product matches, processing continues normally.\n-->\n<fragment>\n    <choose>\n        <!--
# Check if NONE of the allowed products match the context product name -->\n        <when condition=\"@{\n            var allowedProducts = context.Variables.GetValueOrDefault<string>(\"products\",
# \"\").ToString().Split(',');\n            var contextProduct = context.Product?.Id ?? string.Empty;\n        \n            // Check if NO allowed product matches the product names in the context\n            return
# !allowedProducts.Any(product => contextProduct.Contains(product));\n        }\">\n            <return-response>\n                <set-status code=\"403\" reason=\"Forbidden\" />\n                <set-body>Access denied -
# no matching product found</set-body>\n            </return-response>\n        </when>\n        <!-- If products match, continue processing (no action needed) -->\n    </choose>\n</fragment>","description":"Proceeds if
# any of the specified products match the context product name."},{"name":"Remove-Request-Headers","policyXml":"<!--\n    - This fragment removes incoming request headers prior to calling a backend or external
# service.\n-->\n<fragment>\n    <!-- Remove APIM API keys to not inadvertently leak them. -->\n    <set-header name=\"api-key\" exists-action=\"delete\" />\n    <set-header name=\"ocp-apim-subscription-key\"
# exists-action=\"delete\" />\n\n    <!-- The Do Not Track (DNT) header is deprecated: https://developer.mozilla.org/en-US/docs/Web/HTTP/Reference/Headers/DNT -->\n    <set-header name=\"DNT\" exists-action=\"delete\"
# />\n</fragment>\n","description":"Removes request headers from the incoming
# request."}]}},"mode":"Incremental","provisioningState":"Succeeded","timestamp":"2025-12-16T00:48:55.5605714Z","duration":"PT1M50.5855875S","correlationId":"3c3c6f49-fec2-4ce7-ade3-794a66c2c5cd","providers":[{"namespace":"Microsoft.Resources","resourceTypes":[{"resourceType":"deployments","locations":[null]}]}],"dependencies":[{"dependsOn":[{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/lawModule","resourceType":"Microsoft.Resources/deployments","resourceName":"lawModule"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/lawModule","resourceType":"Microsoft.Resources/deployments","resourceName":"lawModule","apiVersion":"2025-04-01"}],"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/appInsightsModule","resourceType":"Microsoft.Resources/deployments","resourceName":"appInsightsModule"},{"dependsOn":[{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/appInsightsModule","resourceType":"Microsoft.Resources/deployments","resourceName":"appInsightsModule"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/appInsightsModule","resourceType":"Microsoft.Resources/deployments","resourceName":"appInsightsModule","apiVersion":"2025-04-01"}],"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/apimModule","resourceType":"Microsoft.Resources/deployments","resourceName":"apimModule"},{"dependsOn":[{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/apimModule","resourceType":"Microsoft.Resources/deployments","resourceName":"apimModule"}],"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/pf-Api-Id","resourceType":"Microsoft.Resources/deployments","resourceName":"pf-Api-Id"},{"dependsOn":[{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/apimModule","resourceType":"Microsoft.Resources/deployments","resourceName":"apimModule"}],"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/pf-AuthZ-Match-All","resourceType":"Microsoft.Resources/deployments","resourceName":"pf-AuthZ-Match-All"},{"dependsOn":[{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/apimModule","resourceType":"Microsoft.Resources/deployments","resourceName":"apimModule"}],"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/pf-AuthZ-Match-Any","resourceType":"Microsoft.Resources/deployments","resourceName":"pf-AuthZ-Match-Any"},{"dependsOn":[{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/apimModule","resourceType":"Microsoft.Resources/deployments","resourceName":"apimModule"}],"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/pf-Http-Response-200","resourceType":"Microsoft.Resources/deployments","resourceName":"pf-Http-Response-200"},{"dependsOn":[{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Resources/deployments/apimModule","resourceType":"Microsoft.Resour ...
# World","productAssociationCount":0,"subscriptionResourceId":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/subscriptions/api-hello-world","subscriptionName":"api-hello-world","subscriptionPrimaryKey":"5061f7c695b9429681a0076a4d76e541","subscriptionSecondaryKey":"d67039246f754902bb4ad863398711da"}]}},"outputResources":[{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/apis/hello-world"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/apis/hello-world/diagnostics/applicationinsights"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/apis/hello-world/operations/hello-world-GET-0-hirrplxxsciuy"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/apis/hello-world/operations/hello-world-GET-0-hirrplxxsciuy/policies/policy"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/apis/hello-world/policies/policy"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/loggers/apim-logger"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/policies/policy"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/policyFragments/Api-Id"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/policyFragments/AuthZ-Match-All"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/policyFragments/AuthZ-Match-Any"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/policyFragments/Http-Response-200"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/policyFragments/Product-Match-Any"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/policyFragments/Remove-Request-Headers"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service/apim-hirrplxxsciuy/subscriptions/api-hello-world"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.Insights/components/appi-hirrplxxsciuy"},{"id":"/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.OperationalInsights/workspaces/log-hirrplxxsciuy"}]}}
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnTransformResult [<function _resource_group_transform at 0x000001E7A2169EE0>, <function _x509_from_base64_to_hex_transform at 0x000001E7A2169F80>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnFilterResult []
# WARNING: cli.knack.output: Unable to encode the output with cp1252 encoding. Unsupported characters are discarded.
# DEBUG: cli.knack.cli: Event: Cli.SuccessfulExecute []
# DEBUG: cli.knack.cli: Event: Cli.PostExecute [<function AzCliLogging.deinit_cmd_metadata_logging at 0x000001E7A2131300>]
# INFO: az_command_data_logger: exit code: 0
# INFO: cli.__main__: Command ran in 3.142 seconds (init: 0.783, invoke: 2.359)
# INFO: telemetry.main: Begin splitting cli events and extra events, total events: 1
# INFO: telemetry.client: Accumulated 0 events. Flush the clients.
# INFO: telemetry.main: Finish splitting cli events and extra events, cli events: 1
# INFO: telemetry.save: Save telemetry record of length 3803 in cache file under C:\Users\simonkurtz\.azure\telemetry\20251215230038591
# INFO: telemetry.main: Begin creating telemetry upload process.
# INFO: telemetry.process: Creating upload process: "C:\Program Files\Microsoft SDKs\Azure\CLI2\python.exe C:\Program Files\Microsoft SDKs\Azure\CLI2\Lib\site-packages\azure\cli\telemetry\__init__.pyc
# C:\Users\simonkurtz\.azure C:\Users\simonkurtz\.azure\telemetry\20251215230038591"
# INFO: telemetry.process: Return from creating process 31052
# INFO: telemetry.main: Finish creating telemetry upload process.
# ✅ Deployment retrieved ⌚ 23:00:38.853551 :3s]
#
# ⚙️  az cognitiveservices account list -g apim-infra-simple-apim-10 --debug
#
# Azure CLI: added --debug based on APIM_SAMPLES_LOG_LEVEL=DEBUG
# DEBUG: cli.knack.cli: Command arguments: ['cognitiveservices', 'account', 'list', '-g', 'apim-infra-simple-apim-10', '--debug']
# DEBUG: cli.knack.cli: __init__ debug log:
# Cannot enable color.
# DEBUG: cli.knack.cli: Event: Cli.PreExecute []
# DEBUG: cli.knack.cli: Event: CommandParser.OnGlobalArgumentsCreate [<function CLILogging.on_global_arguments at 0x000001BD0EFB44A0>, <function OutputProducer.on_global_arguments at 0x000001BD0F54D800>, <function
# CLIQuery.on_global_arguments at 0x000001BD0F59F740>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreCommandTableCreate []
# DEBUG: cli.azure.cli.core: Modules found from index for 'cognitiveservices': ['azure.cli.command_modules.cognitiveservices']
# DEBUG: cli.azure.cli.core: Loading command modules:
# DEBUG: cli.azure.cli.core: Name                  Load Time    Groups  Commands
# DEBUG: cli.azure.cli.core: cognitiveservices         0.009        14        56
# DEBUG: cli.azure.cli.core: Total (1)                 0.009        14        56
# DEBUG: cli.azure.cli.core: These extensions are not installed and will be skipped: ['azext_ai_examples', 'azext_next']
# DEBUG: cli.azure.cli.core: Loading extensions:
# DEBUG: cli.azure.cli.core: Name                  Load Time    Groups  Commands  Directory
# DEBUG: cli.azure.cli.core: Total (0)                 0.000         0         0
# DEBUG: cli.azure.cli.core: Loaded 14 groups, 56 commands.
# DEBUG: cli.azure.cli.core: Found a match in the command table.
# DEBUG: cli.azure.cli.core: Raw command  : cognitiveservices account list
# DEBUG: cli.azure.cli.core: Command table: cognitiveservices account list
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreCommandTableTruncate [<function AzCliLogging.init_command_file_logging at 0x000001BD11D21080>]
# DEBUG: cli.azure.cli.core.azlogging: metadata file logging enabled - writing logs to 'C:\Users\simonkurtz\.azure\commands\2025-12-15.23-00-39.cognitiveservices_account_list.15800.log'.
# INFO: az_command_data_logger: command args: cognitiveservices account list -g {} --debug
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreArgumentLoad [<function register_global_subscription_argument.<locals>.add_subscription_parameter at 0x000001BD11D5A5C0>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPostArgumentLoad []
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPostCommandTableCreate [<function register_ids_argument.<locals>.add_ids_arguments at 0x000001BD11D9C900>, <function register_cache_arguments.<locals>.add_cache_arguments at
# 0x000001BD11D9CAE0>, <function register_upcoming_breaking_change_info.<locals>.update_breaking_change_info at 0x000001BD11D9CB80>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnCommandTableLoaded []
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreParseArgs []
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPostParseArgs [<function OutputProducer.handle_output_argument at 0x000001BD0F54D8A0>, <function CLIQuery.handle_query_parameter at 0x000001BD0F59F7E0>, <function
# register_ids_argument.<locals>.parse_ids_arguments at 0x000001BD11D9C9A0>]
# DEBUG: cli.azure.cli.core.commands.client_factory: Getting management service client client_type=CognitiveServicesManagementClient
# DEBUG: cli.azure.cli.core.auth.persistence: build_persistence: location='C:\\Users\\simonkurtz\\.azure\\msal_token_cache.bin', encrypt=True
# DEBUG: cli.azure.cli.core.auth.binary_cache: load: C:\Users\simonkurtz\.azure\msal_http_cache.bin
# DEBUG: urllib3.util.retry: Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# DEBUG: msal.authority: Initializing with Entra authority: https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3
# DEBUG: msal.authority: openid_config("https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/v2.0/.well-known/openid-configuration") = {'token_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/token', 'token_endpoint_auth_methods_supported': ['client_secret_post', 'private_key_jwt', 'client_secret_basic',
# 'self_signed_tls_client_auth'], 'jwks_uri': 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/discovery/v2.0/keys', 'response_modes_supported': ['query', 'fragment', 'form_post'],
# 'subject_types_supported': ['pairwise'], 'id_token_signing_alg_values_supported': ['RS256'], 'response_types_supported': ['code', 'id_token', 'code id_token', 'id_token token'], 'scopes_supported': ['openid', 'profile',
# 'email', 'offline_access'], 'issuer': 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/v2.0', 'request_uri_parameter_supported': False, 'userinfo_endpoint':
# 'https://graph.microsoft.com/oidc/userinfo', 'authorization_endpoint': 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/authorize', 'device_authorization_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/devicecode', 'http_logout_supported': True, 'frontchannel_logout_supported': True, 'end_session_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/logout', 'claims_supported': ['sub', 'iss', 'cloud_instance_name', 'cloud_instance_host_name', 'cloud_graph_host_name', 'msgraph_host',
# 'aud', 'exp', 'iat', 'auth_time', 'acr', 'nonce', 'preferred_username', 'name', 'tid', 'ver', 'at_hash', 'c_hash', 'email'], 'kerberos_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/kerberos', 'mtls_endpoint_aliases': {'token_endpoint': 'https://mtlsauth.microsoft.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/token'},
# 'tls_client_certificate_bound_access_tokens': True, 'tenant_region_scope': 'NA', 'cloud_instance_name': 'microsoftonline.com', 'cloud_graph_host_name': 'graph.windows.net', 'msgraph_host': 'graph.microsoft.com',
# 'rbac_url': 'https://pas.windows.net'}
# DEBUG: msal.application: Broker enabled? True
# DEBUG: cli.azure.cli.core.auth.credential_adaptor: CredentialAdaptor.get_token_info: scopes=('https://management.core.windows.net//.default',), options={}
# DEBUG: cli.azure.cli.core.auth.msal_credentials: UserCredential.acquire_token: scopes=['https://management.core.windows.net//.default'], claims_challenge=None, kwargs={}
# DEBUG: msal.application: Cache hit an AT
# DEBUG: msal.telemetry: Generate or reuse correlation_id: b38fce1b-7413-4760-bc86-dace5dc873bd
# DEBUG: cli.azure.cli.core.sdk.policies: Request URL:
# 'https://management.azure.com/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.CognitiveServices/accounts?api-version=2025-09-01'
# DEBUG: cli.azure.cli.core.sdk.policies: Request method: 'GET'
# DEBUG: cli.azure.cli.core.sdk.policies: Request headers:
# DEBUG: cli.azure.cli.core.sdk.policies:     'Accept': 'application/json'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-client-request-id': 'c8dd1b91-da33-11f0-8493-b85c5c0a1952'
# DEBUG: cli.azure.cli.core.sdk.policies:     'CommandName': 'cognitiveservices account list'
# DEBUG: cli.azure.cli.core.sdk.policies:     'ParameterSetName': '-g --debug'
# DEBUG: cli.azure.cli.core.sdk.policies:     'User-Agent': 'AZURECLI/2.81.0 (MSI) azsdk-python-core/1.35.0 Python/3.13.9 (Windows-11-10.0.26100-SP0)'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Authorization': '*****'
# DEBUG: cli.azure.cli.core.sdk.policies: Request body:
# DEBUG: cli.azure.cli.core.sdk.policies: This request has no body
# DEBUG: urllib3.connectionpool: Starting new HTTPS connection (1): management.azure.com:443
# DEBUG: urllib3.connectionpool: https://management.azure.com:443 "GET
# /subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.CognitiveServices/accounts?api-version=2025-09-01 HTTP/1.1" 200 12
# DEBUG: cli.azure.cli.core.sdk.policies: Response status: 200
# DEBUG: cli.azure.cli.core.sdk.policies: Response headers:
# DEBUG: cli.azure.cli.core.sdk.policies:     'Cache-Control': 'no-cache'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Pragma': 'no-cache'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Content-Length': '12'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Content-Type': 'application/json; charset=utf-8'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Expires': '-1'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-ratelimit-remaining-subscription-reads': '249'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-ratelimit-remaining-subscription-global-reads': '3749'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-request-id': '818281ef-df47-409e-9b9f-377aa0a3dd9c'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-correlation-request-id': '818281ef-df47-409e-9b9f-377aa0a3dd9c'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-routing-request-id': 'EASTUS2:20251216T040040Z:818281ef-df47-409e-9b9f-377aa0a3dd9c'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
# DEBUG: cli.azure.cli.core.sdk.policies:     'X-Content-Type-Options': 'nosniff'
# DEBUG: cli.azure.cli.core.sdk.policies:     'X-Cache': 'CONFIG_NOCACHE'
# DEBUG: cli.azure.cli.core.sdk.policies:     'X-MSEdge-Ref': 'Ref A: C4047C95631D488AA32958506416D9CC Ref B: SN4AA2022301039 Ref C: 2025-12-16T04:00:40Z'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Date': 'Tue, 16 Dec 2025 04:00:41 GMT'
# DEBUG: cli.azure.cli.core.sdk.policies: Response content:
# DEBUG: cli.azure.cli.core.sdk.policies: {"value":[]}
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnTransformResult [<function _resource_group_transform at 0x000001BD11D59EE0>, <function _x509_from_base64_to_hex_transform at 0x000001BD11D59F80>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnFilterResult []
# DEBUG: cli.knack.cli: Event: Cli.SuccessfulExecute []
# DEBUG: cli.knack.cli: Event: Cli.PostExecute [<function AzCliLogging.deinit_cmd_metadata_logging at 0x000001BD11D21300>]
# INFO: az_command_data_logger: exit code: 0
# INFO: cli.__main__: Command ran in 2.090 seconds (init: 0.683, invoke: 1.408)
# INFO: telemetry.main: Begin splitting cli events and extra events, total events: 1
# INFO: telemetry.client: Accumulated 0 events. Flush the clients.
# INFO: telemetry.main: Finish splitting cli events and extra events, cli events: 1
# INFO: telemetry.save: Save telemetry record of length 3811 in cache file under C:\Users\simonkurtz\.azure\telemetry\20251215230041174
# INFO: telemetry.main: Begin creating telemetry upload process.
# INFO: telemetry.process: Creating upload process: "C:\Program Files\Microsoft SDKs\Azure\CLI2\python.exe C:\Program Files\Microsoft SDKs\Azure\CLI2\Lib\site-packages\azure\cli\telemetry\__init__.pyc
# C:\Users\simonkurtz\.azure C:\Users\simonkurtz\.azure\telemetry\20251215230041174"
# INFO: telemetry.process: Return from creating process 22456
# INFO: telemetry.main: Finish creating telemetry upload process.
# ✅ Listed CognitiveService accounts ⌚ 23:00:41.379075 :2s]
#
# ⚙️  az apim list -g apim-infra-simple-apim-10 --debug
#
# Azure CLI: added --debug based on APIM_SAMPLES_LOG_LEVEL=DEBUG
# DEBUG: cli.knack.cli: Command arguments: ['apim', 'list', '-g', 'apim-infra-simple-apim-10', '--debug']
# DEBUG: cli.knack.cli: __init__ debug log:
# Cannot enable color.
# DEBUG: cli.knack.cli: Event: Cli.PreExecute []
# DEBUG: cli.knack.cli: Event: CommandParser.OnGlobalArgumentsCreate [<function CLILogging.on_global_arguments at 0x000001A43E5844A0>, <function OutputProducer.on_global_arguments at 0x000001A43EB21800>, <function
# CLIQuery.on_global_arguments at 0x000001A43EB6F740>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreCommandTableCreate []
# DEBUG: cli.azure.cli.core: Modules found from index for 'apim': ['azure.cli.command_modules.apim']
# DEBUG: cli.azure.cli.core: Loading command modules:
# DEBUG: cli.azure.cli.core: Name                  Load Time    Groups  Commands
# DEBUG: cli.azure.cli.core: apim                      0.017        14        69
# DEBUG: cli.azure.cli.core: Total (1)                 0.017        14        69
# DEBUG: cli.azure.cli.core: These extensions are not installed and will be skipped: ['azext_ai_examples', 'azext_next']
# DEBUG: cli.azure.cli.core: Loading extensions:
# DEBUG: cli.azure.cli.core: Name                  Load Time    Groups  Commands  Directory
# DEBUG: cli.azure.cli.core: Total (0)                 0.000         0         0
# DEBUG: cli.azure.cli.core: Loaded 14 groups, 69 commands.
# DEBUG: cli.azure.cli.core: Found a match in the command table.
# DEBUG: cli.azure.cli.core: Raw command  : apim list
# DEBUG: cli.azure.cli.core: Command table: apim list
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreCommandTableTruncate [<function AzCliLogging.init_command_file_logging at 0x000001A441291080>]
# DEBUG: cli.azure.cli.core.azlogging: metadata file logging enabled - writing logs to 'C:\Users\simonkurtz\.azure\commands\2025-12-15.23-00-42.apim_list.5652.log'.
# INFO: az_command_data_logger: command args: apim list -g {} --debug
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreArgumentLoad [<function register_global_subscription_argument.<locals>.add_subscription_parameter at 0x000001A4412CA5C0>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPostArgumentLoad []
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPostCommandTableCreate [<function register_ids_argument.<locals>.add_ids_arguments at 0x000001A44130C900>, <function register_cache_arguments.<locals>.add_cache_arguments at
# 0x000001A44130CAE0>, <function register_upcoming_breaking_change_info.<locals>.update_breaking_change_info at 0x000001A44130CB80>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnCommandTableLoaded []
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPreParseArgs []
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnPostParseArgs [<function OutputProducer.handle_output_argument at 0x000001A43EB218A0>, <function CLIQuery.handle_query_parameter at 0x000001A43EB6F7E0>, <function
# register_ids_argument.<locals>.parse_ids_arguments at 0x000001A44130C9A0>]
# DEBUG: cli.azure.cli.core.commands.client_factory: Getting management service client client_type=ApiManagementClient
# DEBUG: cli.azure.cli.core.auth.persistence: build_persistence: location='C:\\Users\\simonkurtz\\.azure\\msal_token_cache.bin', encrypt=True
# DEBUG: cli.azure.cli.core.auth.binary_cache: load: C:\Users\simonkurtz\.azure\msal_http_cache.bin
# DEBUG: urllib3.util.retry: Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# DEBUG: msal.authority: Initializing with Entra authority: https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3
# DEBUG: msal.authority: openid_config("https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/v2.0/.well-known/openid-configuration") = {'token_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/token', 'token_endpoint_auth_methods_supported': ['client_secret_post', 'private_key_jwt', 'client_secret_basic',
# 'self_signed_tls_client_auth'], 'jwks_uri': 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/discovery/v2.0/keys', 'response_modes_supported': ['query', 'fragment', 'form_post'],
# 'subject_types_supported': ['pairwise'], 'id_token_signing_alg_values_supported': ['RS256'], 'response_types_supported': ['code', 'id_token', 'code id_token', 'id_token token'], 'scopes_supported': ['openid', 'profile',
# 'email', 'offline_access'], 'issuer': 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/v2.0', 'request_uri_parameter_supported': False, 'userinfo_endpoint':
# 'https://graph.microsoft.com/oidc/userinfo', 'authorization_endpoint': 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/authorize', 'device_authorization_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/devicecode', 'http_logout_supported': True, 'frontchannel_logout_supported': True, 'end_session_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/logout', 'claims_supported': ['sub', 'iss', 'cloud_instance_name', 'cloud_instance_host_name', 'cloud_graph_host_name', 'msgraph_host',
# 'aud', 'exp', 'iat', 'auth_time', 'acr', 'nonce', 'preferred_username', 'name', 'tid', 'ver', 'at_hash', 'c_hash', 'email'], 'kerberos_endpoint':
# 'https://login.microsoftonline.com/16b3c013-d300-468d-ac64-7eda0820b6d3/kerberos', 'mtls_endpoint_aliases': {'token_endpoint': 'https://mtlsauth.microsoft.com/16b3c013-d300-468d-ac64-7eda0820b6d3/oauth2/v2.0/token'},
# 'tls_client_certificate_bound_access_tokens': True, 'tenant_region_scope': 'NA', 'cloud_instance_name': 'microsoftonline.com', 'cloud_graph_host_name': 'graph.windows.net', 'msgraph_host': 'graph.microsoft.com',
# 'rbac_url': 'https://pas.windows.net'}
# DEBUG: msal.application: Broker enabled? True
# DEBUG: cli.azure.cli.core.auth.credential_adaptor: CredentialAdaptor.get_token_info: scopes=('https://management.core.windows.net//.default',), options={}
# DEBUG: cli.azure.cli.core.auth.msal_credentials: UserCredential.acquire_token: scopes=['https://management.core.windows.net//.default'], claims_challenge=None, kwargs={}
# DEBUG: msal.application: Cache hit an AT
# DEBUG: msal.telemetry: Generate or reuse correlation_id: 99f88ff8-26f5-4c5d-9824-da0542676f94
# DEBUG: cli.azure.cli.core.sdk.policies: Request URL:
# 'https://management.azure.com/subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service?api-version=2022-08-01'
# DEBUG: cli.azure.cli.core.sdk.policies: Request method: 'GET'
# DEBUG: cli.azure.cli.core.sdk.policies: Request headers:
# DEBUG: cli.azure.cli.core.sdk.policies:     'Accept': 'application/json'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-client-request-id': 'ca4edad9-da33-11f0-bc3b-b85c5c0a1952'
# DEBUG: cli.azure.cli.core.sdk.policies:     'CommandName': 'apim list'
# DEBUG: cli.azure.cli.core.sdk.policies:     'ParameterSetName': '-g --debug'
# DEBUG: cli.azure.cli.core.sdk.policies:     'User-Agent': 'AZURECLI/2.81.0 (MSI) azsdk-python-core/1.35.0 Python/3.13.9 (Windows-11-10.0.26100-SP0)'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Authorization': '*****'
# DEBUG: cli.azure.cli.core.sdk.policies: Request body:
# DEBUG: cli.azure.cli.core.sdk.policies: This request has no body
# DEBUG: urllib3.connectionpool: Starting new HTTPS connection (1): management.azure.com:443
# DEBUG: urllib3.connectionpool: https://management.azure.com:443 "GET
# /subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/resourceGroups/apim-infra-simple-apim-10/providers/Microsoft.ApiManagement/service?api-version=2022-08-01 HTTP/1.1" 200 2218
# DEBUG: cli.azure.cli.core.sdk.policies: Response status: 200
# DEBUG: cli.azure.cli.core.sdk.policies: Response headers:
# DEBUG: cli.azure.cli.core.sdk.policies:     'Cache-Control': 'no-cache'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Pragma': 'no-cache'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Content-Length': '2218'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Content-Type': 'application/json; charset=utf-8'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Expires': '-1'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-original-request-ids': '7dd1e5e5-23bc-4e97-b7b2-1760b952c9ea'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-ratelimit-remaining-subscription-reads': '249'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-ratelimit-remaining-subscription-global-reads': '3749'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-request-id': '7dd1e5e5-23bc-4e97-b7b2-1760b952c9ea'
# ...
# DEBUG: cli.azure.cli.core.sdk.policies: Request method: 'GET'
# DEBUG: cli.azure.cli.core.sdk.policies: Request headers:
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-client-request-id': '45af75f1-da34-11f0-886f-b85c5c0a1952'
# DEBUG: cli.azure.cli.core.sdk.policies:     'CommandName': 'group delete'
# DEBUG: cli.azure.cli.core.sdk.policies:     'ParameterSetName': '--name -y --debug'
# DEBUG: cli.azure.cli.core.sdk.policies:     'User-Agent': 'AZURECLI/2.81.0 (MSI) azsdk-python-core/1.35.0 Python/3.13.9 (Windows-11-10.0.26100-SP0)'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Authorization': '*****'
# DEBUG: cli.azure.cli.core.sdk.policies: Request body:
# DEBUG: cli.azure.cli.core.sdk.policies: This request has no body
# DEBUG: urllib3.connectionpool: https://management.azure.com:443 "GET
# /subscriptions/5fb73327-9152-4f64-bf8a-90dc0cc4ad8f/operationresults/eyJqb2JJZCI6IlJFU09VUkNFR1JPVVBERUxFVElPTkpPQi1BUElNOjJESU5GUkE6MkRTSU1QTEU6MkRBUElNOjJEMTAtRUFTVFVTMiIsImpvYkxvY2F0aW9uIjoiZWFzdHVzMiJ9?api-version=2024-11-01&t=639014546825600417&c=MIIIpTCCBo2gAwIBAgITFgIgjekYlM3S-_610A_dmsf9qZGAvp4aAchCeYK-FSnr3Mw1HkB8y6bwmRgY
# HTTP/1.1" 200 0
# DEBUG: cli.azure.cli.core.sdk.policies: Response status: 200
# DEBUG: cli.azure.cli.core.sdk.policies: Response headers:
# DEBUG: cli.azure.cli.core.sdk.policies:     'Cache-Control': 'no-cache'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Pragma': 'no-cache'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Expires': '-1'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-ratelimit-remaining-subscription-reads': '249'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-ratelimit-remaining-subscription-global-reads': '3749'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-request-id': 'be0d2da5-ff35-4050-a9a5-34db34e592d4'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-correlation-request-id': 'be0d2da5-ff35-4050-a9a5-34db34e592d4'
# DEBUG: cli.azure.cli.core.sdk.policies:     'x-ms-routing-request-id': 'SOUTHCENTRALUS:20251216T040513Z:be0d2da5-ff35-4050-a9a5-34db34e592d4'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
# DEBUG: cli.azure.cli.core.sdk.policies:     'X-Content-Type-Options': 'nosniff'
# DEBUG: cli.azure.cli.core.sdk.policies:     'X-Cache': 'CONFIG_NOCACHE'
# DEBUG: cli.azure.cli.core.sdk.policies:     'X-MSEdge-Ref': 'Ref A: CFA135DAEA954AD19671A745A1D20D76 Ref B: SN4AA2022303031 Ref C: 2025-12-16T04:05:12Z'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Date': 'Tue, 16 Dec 2025 04:05:13 GMT'
# DEBUG: cli.azure.cli.core.sdk.policies:     'Content-Length': '0'
# DEBUG: cli.azure.cli.core.sdk.policies: Response content:
# DEBUG: cli.azure.cli.core.sdk.policies:
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnTransformResult [<function _resource_group_transform at 0x0000018DAEFC9EE0>, <function _x509_from_base64_to_hex_transform at 0x0000018DAEFC9F80>]
# DEBUG: cli.knack.cli: Event: CommandInvoker.OnFilterResult []
# DEBUG: cli.knack.cli: Event: Cli.SuccessfulExecute []
# DEBUG: cli.knack.cli: Event: Cli.PostExecute [<function AzCliLogging.deinit_cmd_metadata_logging at 0x0000018DAEF91300>]
# INFO: az_command_data_logger: exit code: 0
# INFO: cli.__main__: Command ran in 65.824 seconds (init: 1.642, invoke: 64.181)
# INFO: telemetry.main: Begin splitting cli events and extra events, total events: 1
# INFO: telemetry.client: Accumulated 0 events. Flush the clients.
# INFO: telemetry.main: Finish splitting cli events and extra events, cli events: 1
# INFO: telemetry.save: Save telemetry record of length 3827 in cache file under C:\Users\simonkurtz\.azure\telemetry\20251215230513407
# INFO: telemetry.main: Begin creating telemetry upload process.
# INFO: telemetry.process: Creating upload process: "C:\Program Files\Microsoft SDKs\Azure\CLI2\python.exe C:\Program Files\Microsoft SDKs\Azure\CLI2\Lib\site-packages\azure\cli\telemetry\__init__.pyc
# C:\Users\simonkurtz\.azure C:\Users\simonkurtz\.azure\telemetry\20251215230513407"
# INFO: telemetry.process: Return from creating process 33476
# INFO: telemetry.main: Finish creating telemetry upload process.
# ✅ Resource group 'apim-infra-simple-apim-10' deleted ⌚ 23:05:14.091632 :6s]
# ℹ️ Cleanup completed. ⌚ 23:05:14.092650
