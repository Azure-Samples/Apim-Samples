# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
from apimtypes import INFRASTRUCTURE
from infrastructures import cleanup_infra_deployments

indexes = [1]

cleanup_infra_deployments(INFRASTRUCTURE.SIMPLE_APIM, indexes)
# Out:
# 👉🏽 Cleaning up resources for simple-apim - 1
# 👉🏽 Resource group : apim-infra-simple-apim-1
# 👉🏽 Found 1 resource(s) to clean up. Processing in parallel...
# 👉🏽 Starting parallel cleanup of 1 resource(s) with 1 worker(s)...
# 👉🏽 Deleting and purging apim 'apim-pwpn7jvwjh7em'...
# ✅ ✓ Cleaned up apim 'apim-pwpn7jvwjh7em' (1/1) ⌚ 15:32:07.104892
#
# ✅ All 1 resource(s) cleaned up successfully! ⌚ 15:32:07.104892
# ℹ️ Deleting resource group 'apim-infra-simple-apim-1'... ⌚ 15:32:07.104892
# ℹ️ Cleanup completed. ⌚ 15:33:26.835597
