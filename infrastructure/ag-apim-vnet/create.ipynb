# %% [markdown]
# ### 🛠️ Configure Infrastructure Parameters & Create the Infrastructure
#
# Set your desired parameters for the AG-APIM-VNET infrastructure deployment.
#
# ❗️ **Modify entries under _User-defined parameters_**.
#
# 🔐 **Important**: After deployment, you'll need to install a self-signed certificate to avoid SSL warnings when testing HTTPS endpoints. This can be done using the Python cell below.

# %%
import utils
from apimtypes import *

# ------------------------------
#    USER CONFIGURATION
# ------------------------------

rg_location = 'eastus2'             # Azure region for deployment
index       = 1                     # Infrastructure index (use different numbers for multiple environments)
apim_sku    = APIM_SKU.DEVELOPER    # Options: 'DEVELOPER', 'STANDARDV2', 'PREMIUMV2'



# ------------------------------
#    SYSTEM CONFIGURATION
# ------------------------------

inb_helper = utils.InfrastructureNotebookHelper(rg_location, INFRASTRUCTURE.AG_APIM_VNET, index, apim_sku) 
inb_helper.create_infrastructure()

utils.print_ok('All done!')

# %% [markdown]
# ### 🔐 Install Certificate (Required for HTTPS Testing)
#
# ⚠️ **This step is required to avoid SSL certificate warnings when testing Application Gateway HTTPS endpoints.**
#
# The deployment creates an HTTPS-only Application Gateway with a certificate. The system now uses a **Root Certificate Authority (CA)** approach for better security and easier management.
#
# **🆕 New CA-Based Certificate System:**
# - **One-time setup**: Install the APIM Samples Root CA once per machine
# - **Automatic trust**: All future infrastructure certificates are automatically trusted
# - **Better security**: Proper certificate hierarchy instead of individual self-signed certificates
# - **Easy management**: Remove all certificates at once if needed
#
# **Certificate Details:**
# - Certificate name: `apim-samples-{resourceGroupName}`
# - Stored securely in Azure Key Vault
# - Cross-platform installation support (Windows, macOS, Linux)
# - Automatic fallback to individual certificates if needed
#
# **📋 What happens when you run the cell below:**
# 1. **Root CA Check**: Verifies if APIM Samples Root CA exists locally and in trust store
# 2. **User Prompt**: If not found, asks permission to create and install the Root CA (one-time setup)
# 3. **CA Creation**: Creates the Root CA certificate and installs it in your trust store
# 4. **Certificate Check**: Verifies if your infrastructure uses CA-signed or self-signed certificates
# 5. **Smart Installation**: Automatically handles the appropriate certificate installation method

# %%
# Install certificate using the new CA-based approach
success = utils.install_infrastructure_certificate_with_guidance(INFRASTRUCTURE.AG_APIM_VNET, index, inb_helper.rg_name)

# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished experimenting, it's advisable to remove all associated resources from Azure to avoid unnecessary cost.
# Use the [clean-up notebook](clean-up.ipynb) for that.
